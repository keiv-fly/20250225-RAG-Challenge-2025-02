# %%
import pandas as pd

from pypdf import PdfReader, PdfWriter
import picologging as logging

import pathlib
import datetime

# %%
now = datetime.datetime.now()
now_str = now.strftime("%Y%m%d_%H%M%S")
pathlib.Path(f"../notebooks_logging/05_cut_pdfs").mkdir(parents=True, exist_ok=True)
# pathlib.Path(f"../notebooks_logging/05_cut_pdfs/{now_str}").mkdir(parents=True, exist_ok=True)

file_handler = logging.FileHandler(f"../notebooks_logging/05_cut_pdfs/{now_str}.log")
stream_handler = logging.StreamHandler()
# stdout_formatter = logging.Formatter(fmt="%(message)s") 
# stream_handler.setFormatter(stdout_formatter)
logging.basicConfig(
    encoding='utf-8', 
    format='%(asctime)s | %(levelname)s | %(message)s', 
    level=logging.INFO, 
    datefmt='%Y-%m-%dT%H:%M:%S',
    handlers=[
        file_handler,
        stream_handler,
    ],
    force=True
)
logger = logging.getLogger()
logger.setLevel(logging.INFO)
li = logger.info
li("start")
# Out:
# 2025-02-26T15:58:25 | INFO | start

# %%
df_subset = pd.read_parquet(f"../data_temp/04 subset.parquet")
df_subset.columns
# df_subset[["sha1", "is_in_questions"]]
# Out:
# Index(['sha1', 'cur', 'company_name', 'major_industry',
#        'mentions_recent_mergers_and_acquisitions', 'has_leadership_changes',
#        'has_layoffs', 'has_executive_compensation',
#        'has_rnd_investment_numbers', 'has_new_product_launches',
#        'has_capital_expenditures', 'has_financial_performance_indicators',
#        'has_dividend_policy_changes', 'has_share_buyback_plans',
#        'has_capital_structure_changes', 'mentions_new_risk_factors',
#        'has_guidance_updates', 'has_regulatory_or_litigation_issues',
#        'has_strategic_restructuring', 'has_supply_chain_disruptions',
#        'has_esg_initiatives', 'is_in_questions'],
#       dtype='object')

# %%
df_subset_filtered = df_subset[df_subset["is_in_questions"]==True]
df_subset_filtered
# Out:
#                                         sha1  cur  \
# 9   601aba58deffc81230c837404aa883de0d1dde1c  USD
# 10  612279ce81b538da24834af47131cc73e8c01a80  USD
# 13  63688d5d0b4f12e9f847c5407439a1ec46047a4a  USD
# 14  69a9dcb0bb6a46e2ff9f969d035e1774a2d49ef1  USD
# 15  69b472e4c05986db72ff8e547bb220e2d222b7ef  USD
# 17  7820b6e9487202b30f2883a6df91ae76f9461f2f  USD
# 19  7c55d7900a241e732c145687598d43c915a678f9  USD
# 21  8dd1306c26c63913495fe81dde5180033b39fc44  AUD
# 25  9cc771c2171bacc138cda4e7d68b8b427a514d81  EUR
# 26  a34c22665bada80d76b98b0e794096aefc06758a  USD
# 27  a6f23184a87f3343f17e8e8ed08f604615cdefc1  AUD
# 29  c51f3c5aff7bea6fbc0bb7537838fa2f44f35c23  USD
# 32  d3a834539b046a49708161a6c0d35aad29dd15ec  USD
# 33  da8afefdc3840175c9f26a4dbbed05e250a342cc  GBP
# 34  dda7722dd2e90c9942ed383957b527873cc74174  EUR
# 36  ed55750eae9cb7d893e6484b92496639172717cd  GBP
# 37  f393170837ab7636d83fdc105279dfc61ebeb017  USD
# 38  f75ff9d631e7efdb86db68ab8ba395de221d9019  EUR
#
#                        company_name         major_industry  \
# 9         Audalia Resources Limited             Technology
# 10                    Enerflex Ltd.   Energy and Utilities
# 13             Altech Chemicals Ltd             Technology
# 14                 HV Bancorp, Inc.     Financial Services
# 15                   Zymeworks Inc.             Healthcare
# 17       Winnebago Industries, Inc.             Automotive
# 19        Canadian Tire Corporation                 Retail
# 21             Alien Metals Limited             Technology
# 25                        Cofinimmo             Healthcare
# 26  Maxeon Solar Technologies, Ltd.   Energy and Utilities
# 27                    Hagerty, Inc.     Financial Services
# 29                    Lipocine Inc.             Healthcare
# 32          Charles & Colvard, Ltd.        Pharmaceuticals
# 33                       Renold plc  Transport & Logistics
# 34                             LVMH                 Retail
# 36               Harworth Group plc  Transport & Logistics
# 37         Johns Lyng Group Limited             Technology
# 38                      Nevro Corp.             Healthcare
#
#     mentions_recent_mergers_and_acquisitions  has_leadership_changes  \
# 9                                      False                    True
# 10                                      True                    True
# 13                                      True                   False
# 14                                      True                   False
# 15                                      True                   False
# 17                                      True                    True
# 19                                      True                    True
# 21                                      True                    True
# 25                                      True                   False
# 26                                     False                   False
# 27                                      True                    True
# 29                                      True                   False
# 32                                     False                    True
# 33                                      True                    True
# 34                                      True                   False
# 36                                     False                    True
# 37                                      True                    True
# 38                                     False                   False
#
#     has_layoffs  has_executive_compensation  has_rnd_investment_numbers  \
# 9         False                        True                        True
# 10        False                        True                       False
# 13        False                        True                        True
# 14        False                        True                       False
# 15        False                        True                        True
# 17        False                        True                       False
# 19        False                        True                        True
# 21        False                        True                       False
# 25        False                        True                        True
# 26        False                        True                        True
# 27         True                        True                        True
# 29        False                        True                        True
# 32        False                        True                       False
# 33        False                        True                        True
# 34        False                        True                        True
# 36        False                        True                       False
# 37        False                        True                       False
# 38        False                        True                        True
#
#     has_new_product_launches  ...  has_dividend_policy_changes  \
# 9                       True  ...                        False
# 10                      True  ...                         True
# 13                      True  ...                        False
# 14                      True  ...                        False
# 15                      True  ...                        False
# 17                      True  ...                         True
# 19                      True  ...                         True
# 21                     False  ...                        False
# 25                     False  ...                         True
# 26                      True  ...                        False
# 27                      True  ...                        False
# 29                      True  ...                        False
# 32                      True  ...                        False
# 33                      True  ...                        False
# 34                      True  ...                        False
# 36                      True  ...                         True
# 37                      True  ...                         True
# 38                      True  ...                        False
#
#     has_share_buyback_plans  has_capital_structure_changes  \
# 9                     False                          False
# 10                    False                           True
# 13                    False                          False
# 14                     True                          False
# 15                    False                          False
# 17                     True                           True
# 19                     True                          False
# 21                    False                           True
# 25                    False                          False
# 26                    False                          False
# 27                    False                          False
# 29                    False                          False
# 32                    False                          False
# 33                     True                           True
# 34                    False                          False
# 36                    False                          False
# 37                    False                          False
# 38                    False                          False
#
#     mentions_new_risk_factors  has_guidance_updates  \
# 9                        True                 False
# 10                       True                  True
# 13                       True                 False
# 14                       True                 False
# 15                       True                  True
# 17                       True                 False
# 19                       True                  True
# 21                       True                 False
# 25                       True                  True
# 26                       True                 False
# 27                       True                  True
# 29                       True                 False
# 32                       True                  True
# 33                       True                  True
# 34                       True                  True
# 36                       True                 False
# 37                      False                 False
# 38                       True                 False
#
#     has_regulatory_or_litigation_issues  has_strategic_restructuring  \
# 9                                 False                        False
# 10                                 True                         True
# 13                                False                        False
# 14                                False                        False
# 15                                 True                        False
# 17                                 True                        False
# 19                                False                        False
# 21                                False                        False
# 25                                False                        False
# 26                                 True                        False
# 27                                 True                         True
# 29                                 True                        False
# 32                                 True                        False
# 33                                False                         True
# 34                                False                        False
# 36                                False                        False
# 37                                False                        False
# 38                                 True                        False
#
#     has_supply_chain_disruptions  has_esg_initiatives  is_in_questions
# 9                          False                False             True
# 10                          True                 True             True
# 13                         False                 True             True
# 14                         False                False             True
# 15                         False                False             True
# 17                          True                 True             True
# 19                          True                 True             True
# 21                         False                False             True
# 25                         False                 True             True
# 26                          True                False             True
# 27                         False                False             True
# 29                         False                False             True
# 32                          True                 True             True
# 33                          True                 True             True
# 34                          True                 True             True
# 36                         False                 True             True
# 37                         False                 True             True
# 38                          True                False             True
#
# [18 rows x 22 columns]

# %%
li(df_subset_filtered)
# Out:
# 2025-02-26T15:58:25 | INFO |                                         sha1  cur  \
# 9   601aba58deffc81230c837404aa883de0d1dde1c  USD
# 10  612279ce81b538da24834af47131cc73e8c01a80  USD
# 13  63688d5d0b4f12e9f847c5407439a1ec46047a4a  USD
# 14  69a9dcb0bb6a46e2ff9f969d035e1774a2d49ef1  USD
# 15  69b472e4c05986db72ff8e547bb220e2d222b7ef  USD
# 17  7820b6e9487202b30f2883a6df91ae76f9461f2f  USD
# 19  7c55d7900a241e732c145687598d43c915a678f9  USD
# 21  8dd1306c26c63913495fe81dde5180033b39fc44  AUD
# 25  9cc771c2171bacc138cda4e7d68b8b427a514d81  EUR
# 26  a34c22665bada80d76b98b0e794096aefc06758a  USD
# 27  a6f23184a87f3343f17e8e8ed08f604615cdefc1  AUD
# 29  c51f3c5aff7bea6fbc0bb7537838fa2f44f35c23  USD
# 32  d3a834539b046a49708161a6c0d35aad29dd15ec  USD
# 33  da8afefdc3840175c9f26a4dbbed05e250a342cc  GBP
# 34  dda7722dd2e90c9942ed383957b527873cc74174  EUR
# 36  ed55750eae9cb7d893e6484b92496639172717cd  GBP
# 37  f393170837ab7636d83fdc105279dfc61ebeb017  USD
# 38  f75ff9d631e7efdb86db68ab8ba395de221d9019  EUR
#
#                        company_name         major_industry  \
# 9         Audalia Resources Limited             Technology
# 10                    Enerflex Ltd.   Energy and Utilities
# 13             Altech Chemicals Ltd             Technology
# 14                 HV Bancorp, Inc.     Financial Services
# 15                   Zymeworks Inc.             Healthcare
# 17       Winnebago Industries, Inc.             Automotive
# 19        Canadian Tire Corporation                 Retail
# 21             Alien Metals Limited             Technology
# 25                        Cofinimmo             Healthcare
# 26  Maxeon Solar Technologies, Ltd.   Energy and Utilities
# 27                    Hagerty, Inc.     Financial Services
# 29                    Lipocine Inc.             Healthcare
# 32          Charles & Colvard, Ltd.        Pharmaceuticals
# 33                       Renold plc  Transport & Logistics
# 34                             LVMH                 Retail
# 36               Harworth Group plc  Transport & Logistics
# 37         Johns Lyng Group Limited             Technology
# 38                      Nevro Corp.             Healthcare
#
#     mentions_recent_mergers_and_acquisitions  has_leadership_changes  \
# 9                                      False                    True
# 10                                      True                    True
# 13                                      True                   False
# 14                                      True                   False
# 15                                      True                   False
# 17                                      True                    True
# 19                                      True                    True
# 21                                      True                    True
# 25                                      True                   False
# 26                                     False                   False
# 27                                      True                    True
# 29                                      True                   False
# 32                                     False                    True
# 33                                      True                    True
# 34                                      True                   False
# 36                                     False                    True
# 37                                      True                    True
# 38                                     False                   False
#
#     has_layoffs  has_executive_compensation  has_rnd_investment_numbers  \
# 9         False                        True                        True
# 10        False                        True                       False
# 13        False                        True                        True
# 14        False                        True                       False
# 15        False                        True                        True
# 17        False                        True                       False
# 19        False                        True                        True
# 21        False                        True                       False
# 25        False                        True                        True
# 26        False                        True                        True
# 27         True                        True                        True
# 29        False                        True                        True
# 32        False                        True                       False
# 33        False                        True                        True
# 34        False                        True                        True
# 36        False                        True                       False
# 37        False                        True                       False
# 38        False                        True                        True
#
#     has_new_product_launches  ...  has_dividend_policy_changes  \
# 9                       True  ...                        False
# 10                      True  ...                         True
# 13                      True  ...                        False
# 14                      True  ...                        False
# 15                      True  ...                        False
# 17                      True  ...                         True
# 19                      True  ...                         True
# 21                     False  ...                        False
# 25                     False  ...                         True
# 26                      True  ...                        False
# 27                      True  ...                        False
# 29                      True  ...                        False
# 32                      True  ...                        False
# 33                      True  ...                        False
# 34                      True  ...                        False
# 36                      True  ...                         True
# 37                      True  ...                         True
# 38                      True  ...                        False
#
#     has_share_buyback_plans  has_capital_structure_changes  \
# 9                     False                          False
# 10                    False                           True
# 13                    False                          False
# 14                     True                          False
# 15                    False                          False
# 17                     True                           True
# 19                     True                          False
# 21                    False                           True
# 25                    False                          False
# 26                    False                          False
# 27                    False                          False
# 29                    False                          False
# 32                    False                          False
# 33                     True                           True
# 34                    False                          False
# 36                    False                          False
# 37                    False                          False
# 38                    False                          False
#
#     mentions_new_risk_factors  has_guidance_updates  \
# 9                        True                 False
# 10                       True                  True
# 13                       True                 False
# 14                       True                 False
# 15                       True                  True
# 17                       True                 False
# 19                       True                  True
# 21                       True                 False
# 25                       True                  True
# 26                       True                 False
# 27                       True                  True
# 29                       True                 False
# 32                       True                  True
# 33                       True                  True
# 34                       True                  True
# 36                       True                 False
# 37                      False                 False
# 38                       True                 False
#
#     has_regulatory_or_litigation_issues  has_strategic_restructuring  \
# 9                                 False                        False
# 10                                 True                         True
# 13                                False                        False
# 14                                False                        False
# 15                                 True                        False
# 17                                 True                        False
# 19                                False                        False
# 21                                False                        False
# 25                                False                        False
# 26                                 True                        False
# 27                                 True                         True
# 29                                 True                        False
# 32                                 True                        False
# 33                                False                         True
# 34                                False                        False
# 36                                False                        False
# 37                                False                        False
# 38                                 True                        False
#
#     has_supply_chain_disruptions  has_esg_initiatives  is_in_questions
# 9                          False                False             True
# 10                          True                 True             True
# 13                         False                 True             True
# 14                         False                False             True
# 15                         False                False             True
# 17                          True                 True             True
# 19                          True                 True             True
# 21                         False                False             True
# 25                         False                 True             True
# 26                          True                False             True
# 27                         False                False             True
# 29                         False                False             True
# 32                          True                 True             True
# 33                          True                 True             True
# 34                          True                 True             True
# 36                         False                 True             True
# 37                         False                 True             True
# 38                          True                False             True
#
# [18 rows x 22 columns]

# %%
pdf_name_i = df_subset_filtered["sha1"].iloc[0] + ".pdf"
pdf_name_i
# Out:
# '601aba58deffc81230c837404aa883de0d1dde1c.pdf'

# %%
li("Cutting pdfs:")

total_pages = 0

for id_row, row in df_subset_filtered.iterrows():
    pdf_name_i = row["sha1"]
    pdf_name_i_w_pdf = pdf_name_i + ".pdf"
    li(f"pdf_name_i={pdf_name_i_w_pdf}")

    reader = PdfReader(f"../data_in/temp/pdfs/pdfs/{pdf_name_i_w_pdf}")

    pathlib.Path(f"../data_temp/05_cut_pdfs/{pdf_name_i}").mkdir(parents=True, exist_ok=True)
    for i, page in enumerate(reader.pages):
        writer = PdfWriter()
        writer.add_page(page)
        with open(f"../data_temp/05_cut_pdfs/{pdf_name_i}/{pdf_name_i}_{i:04d}.pdf", 'wb') as out:
            writer.write(out)
        
        if i == 0 or i == len(reader.pages) - 1 or (i % 100) == 0:
            li(f"page={i}, path=../data_temp/05_cut_pdfs/{pdf_name_i}/{pdf_name_i}_{i:04d}.pdf")    
        total_pages += 1

li(f"total_pages={total_pages}")
# Out:
# 2025-02-26T16:00:26 | INFO | Cutting pdfs:
# 2025-02-26T16:00:26 | INFO | pdf_name_i=601aba58deffc81230c837404aa883de0d1dde1c.pdf
# 2025-02-26T16:00:26 | INFO | page=0, path=../data_temp/05_cut_pdfs/601aba58deffc81230c837404aa883de0d1dde1c/601aba58deffc81230c837404aa883de0d1dde1c_0000.pdf
# 2025-02-26T16:00:27 | INFO | page=58, path=../data_temp/05_cut_pdfs/601aba58deffc81230c837404aa883de0d1dde1c/601aba58deffc81230c837404aa883de0d1dde1c_0058.pdf
# 2025-02-26T16:00:27 | INFO | pdf_name_i=612279ce81b538da24834af47131cc73e8c01a80.pdf
# 2025-02-26T16:00:27 | INFO | page=0, path=../data_temp/05_cut_pdfs/612279ce81b538da24834af47131cc73e8c01a80/612279ce81b538da24834af47131cc73e8c01a80_0000.pdf
# 2025-02-26T16:00:28 | INFO | page=100, path=../data_temp/05_cut_pdfs/612279ce81b538da24834af47131cc73e8c01a80/612279ce81b538da24834af47131cc73e8c01a80_0100.pdf
# 2025-02-26T16:00:28 | INFO | page=107, path=../data_temp/05_cut_pdfs/612279ce81b538da24834af47131cc73e8c01a80/612279ce81b538da24834af47131cc73e8c01a80_0107.pdf
# 2025-02-26T16:00:28 | INFO | pdf_name_i=63688d5d0b4f12e9f847c5407439a1ec46047a4a.pdf
# 2025-02-26T16:00:28 | INFO | page=0, path=../data_temp/05_cut_pdfs/63688d5d0b4f12e9f847c5407439a1ec46047a4a/63688d5d0b4f12e9f847c5407439a1ec46047a4a_0000.pdf
# 2025-02-26T16:00:29 | INFO | page=91, path=../data_temp/05_cut_pdfs/63688d5d0b4f12e9f847c5407439a1ec46047a4a/63688d5d0b4f12e9f847c5407439a1ec46047a4a_0091.pdf
# 2025-02-26T16:00:29 | INFO | pdf_name_i=69a9dcb0bb6a46e2ff9f969d035e1774a2d49ef1.pdf
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 16 0 (offset 0)
# Ignoring wrong pointing object 19 0 (offset 0)
# Ignoring wrong pointing object 21 0 (offset 0)
# Ignoring wrong pointing object 26 0 (offset 0)
# Ignoring wrong pointing object 31 0 (offset 0)
# Ignoring wrong pointing object 33 0 (offset 0)
# Ignoring wrong pointing object 41 0 (offset 0)
# Ignoring wrong pointing object 43 0 (offset 0)
# Ignoring wrong pointing object 48 0 (offset 0)
# Ignoring wrong pointing object 50 0 (offset 0)
# Ignoring wrong pointing object 117 0 (offset 0)
# Ignoring wrong pointing object 128 0 (offset 0)
# Ignoring wrong pointing object 133 0 (offset 0)
# Ignoring wrong pointing object 138 0 (offset 0)
# Ignoring wrong pointing object 144 0 (offset 0)
# Ignoring wrong pointing object 149 0 (offset 0)
# Ignoring wrong pointing object 157 0 (offset 0)
# Ignoring wrong pointing object 168 0 (offset 0)
# Ignoring wrong pointing object 170 0 (offset 0)
# Ignoring wrong pointing object 197 0 (offset 0)
# Ignoring wrong pointing object 199 0 (offset 0)
# Ignoring wrong pointing object 211 0 (offset 0)
# Ignoring wrong pointing object 217 0 (offset 0)
# Ignoring wrong pointing object 222 0 (offset 0)
# 2025-02-26T16:00:33 | INFO | page=0, path=../data_temp/05_cut_pdfs/8dd1306c26c63913495fe81dde5180033b39fc44/8dd1306c26c63913495fe81dde5180033b39fc44_0000.pdf
# 2025-02-26T16:00:33 | INFO | page=53, path=../data_temp/05_cut_pdfs/8dd1306c26c63913495fe81dde5180033b39fc44/8dd1306c26c63913495fe81dde5180033b39fc44_0053.pdf
# 2025-02-26T16:00:33 | INFO | pdf_name_i=9cc771c2171bacc138cda4e7d68b8b427a514d81.pdf
# 2025-02-26T16:00:34 | INFO | page=0, path=../data_temp/05_cut_pdfs/9cc771c2171bacc138cda4e7d68b8b427a514d81/9cc771c2171bacc138cda4e7d68b8b427a514d81_0000.pdf
# 2025-02-26T16:00:35 | INFO | page=100, path=../data_temp/05_cut_pdfs/9cc771c2171bacc138cda4e7d68b8b427a514d81/9cc771c2171bacc138cda4e7d68b8b427a514d81_0100.pdf
# 2025-02-26T16:00:36 | INFO | page=200, path=../data_temp/05_cut_pdfs/9cc771c2171bacc138cda4e7d68b8b427a514d81/9cc771c2171bacc138cda4e7d68b8b427a514d81_0200.pdf
# 2025-02-26T16:00:36 | INFO | page=300, path=../data_temp/05_cut_pdfs/9cc771c2171bacc138cda4e7d68b8b427a514d81/9cc771c2171bacc138cda4e7d68b8b427a514d81_0300.pdf
# 2025-02-26T16:00:37 | INFO | page=383, path=../data_temp/05_cut_pdfs/9cc771c2171bacc138cda4e7d68b8b427a514d81/9cc771c2171bacc138cda4e7d68b8b427a514d81_0383.pdf
# 2025-02-26T16:00:37 | INFO | pdf_name_i=a34c22665bada80d76b98b0e794096aefc06758a.pdf
# 2025-02-26T16:00:37 | INFO | page=0, path=../data_temp/05_cut_pdfs/a34c22665bada80d76b98b0e794096aefc06758a/a34c22665bada80d76b98b0e794096aefc06758a_0000.pdf
