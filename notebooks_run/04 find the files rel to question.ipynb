# %%
import openai
import pandas as pd
import tqdm

import picologging as logging

from pydantic import BaseModel, Field

from typing import Optional, List, Union, Literal
import json
import datetime
import pathlib

# %%
with open("../tokens/openai_token.txt") as f:
    openai_token = f.read()

# %%
now = datetime.datetime.now()
now_str = now.strftime("%Y%m%d_%H%M%S")
pathlib.Path(f"../notebooks_logging/find_files").mkdir(parents=True, exist_ok=True)
pathlib.Path(f"../notebooks_logging/find_files/{now_str}").mkdir(parents=True, exist_ok=True)

file_handler = logging.FileHandler(f"../notebooks_logging/find_files/{now_str}.log")
stream_handler = logging.StreamHandler()
# stdout_formatter = logging.Formatter(fmt="%(message)s") 
# stream_handler.setFormatter(stdout_formatter)
logging.basicConfig(
    encoding='utf-8', 
    format='%(asctime)s | %(levelname)s | %(message)s', 
    level=logging.INFO, 
    datefmt='%Y-%m-%dT%H:%M:%S',
    handlers=[
        file_handler,
        stream_handler,
    ],
    force=True
)
logger = logging.getLogger()
logger.setLevel(logging.INFO)
li = logger.info
li("start")
# Out:
# 2025-02-24T22:04:27 | INFO | start

# %%
class Question(BaseModel):
    text: str
    kind: Literal["number", "name", "boolean", "names"]

class SourceReference(BaseModel):
    pdf_sha1: str = Field(..., description="SHA1 hash of the PDF file")
    page_index: int = Field(..., description="Physical page number in the PDF file")

class Answer(BaseModel):
    question_text: Optional[str] = Field(None, description="Text of the question")
    kind: Optional[Literal["number", "name", "boolean", "names"]] = Field(None, description="Kind of the question")
    value: Union[float, str, bool, List[str], Literal["N/A"]] = Field(..., description="Answer to the question, according to the question schema")
    references: List[SourceReference] = Field([], description="References to the source material in the PDF file")

class AnswerSubmission(BaseModel):
    team_email: str = Field(..., description="Email that your team used to register for the challenge")
    submission_name: str = Field(..., description="Unique name of the submission (e.g. experiment name)")
    answers: List[Answer] = Field(..., description="List of answers to the questions")

# %%
li("Questions:")
with open("../data_in/questions.json") as f:
    questions = json.loads(f.read())
questions_typed = [Question(**x) for x in questions]
for q in questions[:5]:
    li(q)

li("Subset:")
with open("../data_in/subset.json") as f:
    subset = json.loads(f.read())
for x in subset[:5]:
    li(x)
# Out:
# 2025-02-24T22:04:27 | INFO | Questions:
# 2025-02-24T22:04:27 | INFO | {'text': "According to the annual report, what is the Operating margin (%) for Altech Chemicals Ltd  (within the last period or at the end of the last period)? If data is not available, return 'N/A'.", 'kind': 'number'}
# 2025-02-24T22:04:27 | INFO | {'text': "According to the annual report, what is the Operating margin (%) for Cofinimmo  (within the last period or at the end of the last period)? If data is not available, return 'N/A'.", 'kind': 'number'}
# 2025-02-24T22:04:27 | INFO | {'text': 'Did Cofinimmo outline any new ESG initiatives in the annual report?', 'kind': 'boolean'}
# 2025-02-24T22:04:27 | INFO | {'text': "What is the total number of employees let go by Hagerty, Inc. according to the annual report? If data is not available, return 'N/A'.", 'kind': 'number'}
# 2025-02-24T22:04:27 | INFO | {'text': "Which leadership **positions** changed at Renold plc in the reporting period? If data is not available, return 'N/A'.", 'kind': 'names'}
# 2025-02-24T22:04:27 | INFO | Subset:
# 2025-02-24T22:04:27 | INFO | {'sha1': '0a9e39e1d2e176f3a766a0e86af82772f1654a6e', 'cur': 'USD', 'company_name': 'KeyCorp', 'major_industry': 'Financial Services', 'mentions_recent_mergers_and_acquisitions': True, 'has_leadership_changes': True, 'has_layoffs': False, 'has_executive_compensation': True, 'has_rnd_investment_numbers': True, 'has_new_product_launches': True, 'has_capital_expenditures': True, 'has_financial_performance_indicators': True, 'has_dividend_policy_changes': True, 'has_share_buyback_plans': True, 'has_capital_structure_changes': False, 'mentions_new_risk_factors': True, 'has_guidance_updates': True, 'has_regulatory_or_litigation_issues': True, 'has_strategic_restructuring': False, 'has_supply_chain_disruptions': False, 'has_esg_initiatives': True}
# 2025-02-24T22:04:27 | INFO | {'sha1': '20c4badd4303f7aba1a298d84be3722fa84e0c67', 'cur': 'USD', 'company_name': 'Summit Materials, Inc.', 'major_industry': 'Financial Services', 'mentions_recent_mergers_and_acquisitions': True, 'has_leadership_changes': True, 'has_layoffs': False, 'has_executive_compensation': True, 'has_rnd_investment_numbers': False, 'has_new_product_launches': False, 'has_capital_expenditures': True, 'has_financial_performance_indicators': True, 'has_dividend_policy_changes': False, 'has_share_buyback_plans': True, 'has_capital_structure_changes': False, 'mentions_new_risk_factors': True, 'has_guidance_updates': False, 'has_regulatory_or_litigation_issues': False, 'has_strategic_restructuring': False, 'has_supply_chain_disruptions': True, 'has_esg_initiatives': True}
# 2025-02-24T22:04:27 | INFO | {'sha1': '30b729c124a24ff21f37431dab6b58dfe7ba56fa', 'cur': 'USD', 'company_name': 'Gibson Energy Inc.', 'major_industry': 'Energy and Utilities', 'mentions_recent_mergers_and_acquisitions': False, 'has_leadership_changes': False, 'has_layoffs': False, 'has_executive_compensation': True, 'has_rnd_investment_numbers': False, 'has_new_product_launches': False, 'has_capital_expenditures': True, 'has_financial_performance_indicators': True, 'has_dividend_policy_changes': True, 'has_share_buyback_plans': True, 'has_capital_structure_changes': False, 'mentions_new_risk_factors': False, 'has_guidance_updates': False, 'has_regulatory_or_litigation_issues': True, 'has_strategic_restructuring': False, 'has_supply_chain_disruptions': False, 'has_esg_initiatives': False}
# 2025-02-24T22:04:27 | INFO | {'sha1': '42f03832077a92b3b34855cb7f9ef93563143838', 'cur': 'EUR', 'company_name': 'HCW Biologics Inc.', 'major_industry': 'Healthcare', 'mentions_recent_mergers_and_acquisitions': True, 'has_leadership_changes': False, 'has_layoffs': False, 'has_executive_compensation': True, 'has_rnd_investment_numbers': True, 'has_new_product_launches': True, 'has_capital_expenditures': True, 'has_financial_performance_indicators': True, 'has_dividend_policy_changes': False, 'has_share_buyback_plans': False, 'has_capital_structure_changes': False, 'mentions_new_risk_factors': True, 'has_guidance_updates': True, 'has_regulatory_or_litigation_issues': True, 'has_strategic_restructuring': False, 'has_supply_chain_disruptions': False, 'has_esg_initiatives': False}
# 2025-02-24T22:04:27 | INFO | {'sha1': '49a9bf0542f3e5ff0250064bfed4369ecf6c8a09', 'cur': 'USD', 'company_name': 'Essential Metals Limited', 'major_industry': 'Technology', 'mentions_recent_mergers_and_acquisitions': True, 'has_leadership_changes': False, 'has_layoffs': False, 'has_executive_compensation': True, 'has_rnd_investment_numbers': True, 'has_new_product_launches': False, 'has_capital_expenditures': True, 'has_financial_performance_indicators': True, 'has_dividend_policy_changes': False, 'has_share_buyback_plans': False, 'has_capital_structure_changes': False, 'mentions_new_risk_factors': True, 'has_guidance_updates': False, 'has_regulatory_or_litigation_issues': False, 'has_strategic_restructuring': False, 'has_supply_chain_disruptions': False, 'has_esg_initiatives': True}

# %%
li("Company names:")
li("---")
subset_companies_list = [x["company_name"] for x in subset]
for x in subset_companies_list:
    li(x)
li("---")
# Out:
# 2025-02-24T22:04:27 | INFO | Company names:
# 2025-02-24T22:04:27 | INFO | ---
# 2025-02-24T22:04:27 | INFO | KeyCorp
# 2025-02-24T22:04:27 | INFO | Summit Materials, Inc.
# 2025-02-24T22:04:27 | INFO | Gibson Energy Inc.
# 2025-02-24T22:04:27 | INFO | HCW Biologics Inc.
# 2025-02-24T22:04:27 | INFO | Essential Metals Limited
# 2025-02-24T22:04:27 | INFO | EVI Industries, Inc.
# 2025-02-24T22:04:27 | INFO | Koenig & Bauer AG
# 2025-02-24T22:04:27 | INFO | Microchip Technology Incorporated
# 2025-02-24T22:04:27 | INFO | Corbus Pharmaceuticals Holdings, Inc.
# 2025-02-24T22:04:27 | INFO | Audalia Resources Limited
# 2025-02-24T22:04:27 | INFO | Enerflex Ltd.
# 2025-02-24T22:04:27 | INFO | MFA Financial, Inc.
# 2025-02-24T22:04:27 | INFO | Strike Resources Limited
# 2025-02-24T22:04:27 | INFO | Altech Chemicals Ltd
# 2025-02-24T22:04:27 | INFO | HV Bancorp, Inc.
# 2025-02-24T22:04:27 | INFO | Zymeworks Inc.
# 2025-02-24T22:04:27 | INFO | iBio, Inc.
# 2025-02-24T22:04:27 | INFO | Winnebago Industries, Inc.
# 2025-02-24T22:04:27 | INFO | Terns Pharmaceuticals, Inc.
# 2025-02-24T22:04:27 | INFO | Canadian Tire Corporation
# 2025-02-24T22:04:27 | INFO | Prodigy Gold NL
# 2025-02-24T22:04:27 | INFO | Alien Metals Limited
# 2025-02-24T22:04:27 | INFO | Urban Logistics REIT plc
# 2025-02-24T22:04:27 | INFO | Xero Limited
# 2025-02-24T22:04:27 | INFO | Dunedin Enterprise Investment Trust PLC
# 2025-02-24T22:04:27 | INFO | Cofinimmo
# 2025-02-24T22:04:27 | INFO | Maxeon Solar Technologies, Ltd.
# 2025-02-24T22:04:27 | INFO | Hagerty, Inc.
# 2025-02-24T22:04:27 | INFO | Universal Electronics Inc.
# 2025-02-24T22:04:27 | INFO | Lipocine Inc.
# 2025-02-24T22:04:27 | INFO | ICICI Bank
# 2025-02-24T22:04:27 | INFO | CareTrust REIT, Inc.
# 2025-02-24T22:04:27 | INFO | Charles & Colvard, Ltd.
# 2025-02-24T22:04:27 | INFO | Renold plc
# 2025-02-24T22:04:27 | INFO | LVMH
# 2025-02-24T22:04:27 | INFO | Advantage Solutions Inc.
# 2025-02-24T22:04:27 | INFO | Harworth Group plc
# 2025-02-24T22:04:27 | INFO | Johns Lyng Group Limited
# 2025-02-24T22:04:27 | INFO | Nevro Corp.
# 2025-02-24T22:04:27 | INFO | Ameresco, Inc.
# 2025-02-24T22:04:27 | INFO | ---

# %%
class CompanyAnswer(BaseModel):
    result: List[str] = Field(..., description="List of company names")
    result_prob: float = Field(..., description="Probability that the result is the right one")

client = openai.OpenAI(
    # This is the default and can be omitted
    api_key=openai_token,
)

progress_bar = tqdm.tqdm(questions)

temp_answers = []

for question in progress_bar:
    li(progress_bar)

    answer = {}
    q_text = question["text"]
    answer["question_text"] = q_text
    q_kind = question["kind"]
    answer["kind"] = q_kind

    msg = "Find company names in this question. There could be zero or more company names"

    msg += """
    ---
    Output format:
    The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
    The output is a JSON that corresponds to the following schema:
    {
        "type": "object",
        "properties": {
            "result": {
                "description": "One company name",
                "type": "array",
                "items": {
                    "type": "string"
                }
            },
            "result_prob": {
                "description": "Probability that the result is the right one. Float from 0 to 1.",
                "type": "number"
            }
        },
        "required": [
            "result",
            "result_prob",
        ]
    }
    """

    msg += f"""
    ---
    Question:
    {q_text}
    """

    li(f"msg=\n{msg}")

    model_answers = []
    for i in range(3):
        chat_completion = client.chat.completions.create(
            messages=[
                {
                    "role": "user",
                    "content": msg,
                }
            ],
            model="o1-mini",
        )
        ans = chat_completion.choices[0].message.content
        ans_l_splitted = ans.split('@@@')
        if len(ans_l_splitted) == 3:
            ans_splitted = ans_l_splitted[1]
            try:
                ans_d = json.loads(ans_splitted)
                _ = CompanyAnswer(**ans_d)
            except:
                ans_d = {
                    "result": ans_splitted,
                    "result_prob": 0.0
                }
        else:
            ans_d = {
                "result": ans,
                "result_prob": 0.0
            }



        model_answers.append(ans_d)

    li(f"model_answers=\n{model_answers}")

    df_result = pd.DataFrame(model_answers)
    df_result["result_prob"] = pd.to_numeric(df_result["result_prob"], errors="coerce")
    max_prob = df_result["result_prob"].fillna(0.0).max()
    df_result["result_str"] = df_result["result"].apply(str)
    df_result["result_votes"] = df_result.groupby(["result_str", "result_prob"]).transform("count")
    df_result_max_prob = df_result[df_result["result_prob"]==max_prob]
    max_votes = df_result_max_prob["result_votes"].max()
    list_companies = df_result_max_prob[df_result_max_prob["result_votes"]==max_votes]["result"].iloc[0]
    li(f"list_companies={list_companies}")

    subset_documents_to_look_through = []

    class ListContainsAnswer(BaseModel):
        result_name: str = Field(..., description="Company name")
        result_list_position: Union[int, Literal["N/A"]] = Field(..., description="Company name")
        result_prob: float = Field(..., description="Probability that the result is the right one")

    #for company in tqdm.notebook.tqdm(list_companies):
    for company in list_companies:
        client = openai.OpenAI(
            # This is the default and can be omitted
            api_key=openai_token,
        )

        msg = "Find this company name in the following list. "

        msg += """
---
Output format:
The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
The output is a JSON that corresponds to the following schema:
{
    "type": "object",
    "properties": {
        "result_name": {
            "description": "The company name found in list. If not found return N/A",
            "type": "string",
        },
        "result_list_position": {
            "description": "The position of the found company in a list. If not found return N/A",
            "type": "string",
        },
        "result_prob": {
            "description": "Probability that the result is the right one. Float from 0 to 1.",
            "type": "number"
        }
    },
    "required": [
        "result",
        "result_list_position",
        "result_prob",
    ]
}
"""

        msg += f"""
---
Company name to find:
{company}
---
List of companies:
"""

        msg+= "\n".join(subset_companies_list)

        li(f"msg=\n{msg}")

        model_answers = []
        for i in range(3):
            chat_completion = client.chat.completions.create(
                messages=[
                    {
                        "role": "user",
                        "content": msg,
                    }
                ],
                model="o1-mini",
            )
            ans = chat_completion.choices[0].message.content
            ans_l_splitted = ans.split('@@@')
            if len(ans_l_splitted) == 3:
                ans_splitted = ans_l_splitted[1]
                try:
                    ans_d = json.loads(ans_splitted)
                    _ = ListContainsAnswer(**ans_d)
                except:
                    ans_d = {
                        "result": ans_splitted,
                        "result_prob": 0.0
                    }
            else:
                ans_d = {
                    "result": ans,
                    "result_prob": 0.0
                }



            model_answers.append(ans_d)
        li(f"model_answers=\n{model_answers}")

        df_result = pd.DataFrame(model_answers)
        df_result["result_prob"] = pd.to_numeric(df_result["result_prob"], errors="coerce")
        max_prob = df_result["result_prob"].fillna(0.0).max()
        df_result["result_str"] = df_result["result_name"].apply(str)
        df_result["result_votes"] = df_result.groupby(["result_str", "result_prob"]).transform("count").loc[:,"result_name"]
        df_result_max_prob = df_result[df_result["result_prob"]==max_prob]
        max_votes = df_result_max_prob["result_votes"].max()
        company_name_in_list = df_result_max_prob[df_result_max_prob["result_votes"]==max_votes]["result_str"].iloc[0]

        df_subset = pd.DataFrame({"subset_company": subset_companies_list})
        subset_documents_to_look_through_i = df_subset[df_subset["subset_company"] == company_name_in_list].index.to_list()
        subset_documents_to_look_through += subset_documents_to_look_through_i

    li(f"subset_documents_to_look_through={subset_documents_to_look_through}")

    answer["documents_to_look_through"] = subset_documents_to_look_through
    temp_answers.append(answer)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]2025-02-24T22:04:28 | INFO |   0%|          | 0/30 [00:00<?, ?it/s]
# 2025-02-24T22:04:28 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
#     The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#     The output is a JSON that corresponds to the following schema:
#     {
#         "type": "object",
#         "properties": {
#             "result": {
#                 "description": "One company name",
#                 "type": "array",
#                 "items": {
#                     "type": "string"
#                 }
#             },
#             "result_prob": {
#                 "description": "Probability that the result is the right one. Float from 0 to 1.",
#                 "type": "number"
#             }
#         },
#         "required": [
#             "result",
#             "result_prob",
#         ]
#     }
#
#     ---
#     Question:
#     According to the annual report, what is the Operating margin (%) for Altech Chemicals Ltd  (within the last period or at the end of the last period)? If data is not available, return 'N/A'.
#
# 2025-02-24T22:04:37 | INFO | model_answers=
# [{'result': ['Altech Chemicals Ltd'], 'result_prob': 1.0}, {'result': ['Altech Chemicals Ltd'], 'result_prob': 1.0}, {'result': ['Altech Chemicals Ltd'], 'result_prob': 1.0}]
# 2025-02-24T22:04:37 | INFO | list_companies=['Altech Chemicals Ltd']
# 2025-02-24T22:04:37 | INFO | msg=
# Find this company name in the following list.
#         ---
#         Output format:
#         The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#         The output is a JSON that corresponds to the following schema:
#         {
#             "type": "object",
#             "properties": {
#                 "result_name": {
#                     "description": "The company name found in list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_list_position": {
#                     "description": "The position of the found company in a list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_prob": {
#                     "description": "Probability that the result is the right one. Float from 0 to 1.",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "result",
#                 "result_list_position",
#                 "result_prob",
#             ]
#         }
#
#         ---
#         Company name to find:
#         Altech Chemicals Ltd
#         ---
#         List of companies:
#         KeyCorp
# Summit Materials, Inc.
# Gibson Energy Inc.
# HCW Biologics Inc.
# Essential Metals Limited
# EVI Industries, Inc.
# Koenig & Bauer AG
# Microchip Technology Incorporated
# Corbus Pharmaceuticals Holdings, Inc.
# Audalia Resources Limited
# Enerflex Ltd.
# MFA Financial, Inc.
# Strike Resources Limited
# Altech Chemicals Ltd
# HV Bancorp, Inc.
# Zymeworks Inc.
# iBio, Inc.
# Winnebago Industries, Inc.
# Terns Pharmaceuticals, Inc.
# Canadian Tire Corporation
# Prodigy Gold NL
# Alien Metals Limited
# Urban Logistics REIT plc
# Xero Limited
# Dunedin Enterprise Investment Trust PLC
# Cofinimmo
# Maxeon Solar Technologies, Ltd.
# Hagerty, Inc.
# Universal Electronics Inc.
# Lipocine Inc.
# ICICI Bank
# CareTrust REIT, Inc.
# Charles & Colvard, Ltd.
# Renold plc
# LVMH
# Advantage Solutions Inc.
# Harworth Group plc
# Johns Lyng Group Limited
# Nevro Corp.
# Ameresco, Inc.
# 2025-02-24T22:04:56 | INFO | model_answers=
# [{'result_name': 'Altech Chemicals Ltd', 'result_list_position': '14', 'result_prob': 1.0}, {'result_name': 'Altech Chemicals Ltd', 'result_list_position': '14', 'result_prob': 1.0}, {'result_name': 'Altech Chemicals Ltd', 'result_list_position': '14', 'result_prob': 1.0}]
# 2025-02-24T22:04:56 | INFO | subset_documents_to_look_through=[13]
#   3%|▎         | 1/30 [00:28<13:42, 28.36s/it]2025-02-24T22:04:56 | INFO |   3%|▎         | 1/30 [00:28<13:42, 28.36s/it]
# 2025-02-24T22:04:56 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
#     The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#     The output is a JSON that corresponds to the following schema:
#     {
#         "type": "object",
#         "properties": {
#             "result": {
#                 "description": "One company name",
#                 "type": "array",
#                 "items": {
#                     "type": "string"
#                 }
#             },
#             "result_prob": {
#                 "description": "Probability that the result is the right one. Float from 0 to 1.",
#                 "type": "number"
#             }
#         },
#         "required": [
#             "result",
#             "result_prob",
#         ]
#     }
#
#     ---
#     Question:
#     According to the annual report, what is the Operating margin (%) for Cofinimmo  (within the last period or at the end of the last period)? If data is not available, return 'N/A'.
#
# 2025-02-24T22:05:06 | INFO | model_answers=
# [{'result': ['Cofinimmo'], 'result_prob': 1.0}, {'result': ['Cofinimmo'], 'result_prob': 1.0}, {'result': ['Cofinimmo'], 'result_prob': 1.0}]
# 2025-02-24T22:05:06 | INFO | list_companies=['Cofinimmo']
# 2025-02-24T22:05:07 | INFO | msg=
# Find this company name in the following list.
#         ---
#         Output format:
#         The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#         The output is a JSON that corresponds to the following schema:
#         {
#             "type": "object",
#             "properties": {
#                 "result_name": {
#                     "description": "The company name found in list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_list_position": {
#                     "description": "The position of the found company in a list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_prob": {
#                     "description": "Probability that the result is the right one. Float from 0 to 1.",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "result",
#                 "result_list_position",
#                 "result_prob",
#             ]
#         }
#
#         ---
#         Company name to find:
#         Cofinimmo
#         ---
#         List of companies:
#         KeyCorp
# Summit Materials, Inc.
# Gibson Energy Inc.
# HCW Biologics Inc.
# Essential Metals Limited
# EVI Industries, Inc.
# Koenig & Bauer AG
# Microchip Technology Incorporated
# Corbus Pharmaceuticals Holdings, Inc.
# Audalia Resources Limited
# Enerflex Ltd.
# MFA Financial, Inc.
# Strike Resources Limited
# Altech Chemicals Ltd
# HV Bancorp, Inc.
# Zymeworks Inc.
# iBio, Inc.
# Winnebago Industries, Inc.
# Terns Pharmaceuticals, Inc.
# Canadian Tire Corporation
# Prodigy Gold NL
# Alien Metals Limited
# Urban Logistics REIT plc
# Xero Limited
# Dunedin Enterprise Investment Trust PLC
# Cofinimmo
# Maxeon Solar Technologies, Ltd.
# Hagerty, Inc.
# Universal Electronics Inc.
# Lipocine Inc.
# ICICI Bank
# CareTrust REIT, Inc.
# Charles & Colvard, Ltd.
# Renold plc
# LVMH
# Advantage Solutions Inc.
# Harworth Group plc
# Johns Lyng Group Limited
# Nevro Corp.
# Ameresco, Inc.
# 2025-02-24T22:05:42 | INFO | model_answers=
# [{'result_name': 'Cofinimmo', 'result_list_position': '26', 'result_prob': 1.0}, {'result_name': 'Cofinimmo', 'result_list_position': '26', 'result_prob': 1.0}, {'result_name': 'Cofinimmo', 'result_list_position': '26', 'result_prob': 1.0}]
# 2025-02-24T22:05:42 | INFO | subset_documents_to_look_through=[25]
#   7%|▋         | 2/30 [01:14<17:59, 38.55s/it]2025-02-24T22:05:42 | INFO |   7%|▋         | 2/30 [01:14<17:59, 38.55s/it]
# 2025-02-24T22:05:42 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
#     The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#     The output is a JSON that corresponds to the following schema:
#     {
#         "type": "object",
#         "properties": {
#             "result": {
#                 "description": "One company name",
#                 "type": "array",
#                 "items": {
#                     "type": "string"
#                 }
#             },
#             "result_prob": {
#                 "description": "Probability that the result is the right one. Float from 0 to 1.",
#                 "type": "number"
#             }
#         },
#         "required": [
#             "result",
#             "result_prob",
#         ]
#     }
#
#     ---
#     Question:
#     Did Cofinimmo outline any new ESG initiatives in the annual report?
#
# 2025-02-24T22:05:51 | INFO | model_answers=
# [{'result': ['Cofinimmo'], 'result_prob': 1.0}, {'result': ['Cofinimmo'], 'result_prob': 1.0}, {'result': ['Cofinimmo'], 'result_prob': 1.0}]
# 2025-02-24T22:05:51 | INFO | list_companies=['Cofinimmo']
# 2025-02-24T22:05:51 | INFO | msg=
# Find this company name in the following list.
#         ---
#         Output format:
#         The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#         The output is a JSON that corresponds to the following schema:
#         {
#             "type": "object",
#             "properties": {
#                 "result_name": {
#                     "description": "The company name found in list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_list_position": {
#                     "description": "The position of the found company in a list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_prob": {
#                     "description": "Probability that the result is the right one. Float from 0 to 1.",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "result",
#                 "result_list_position",
#                 "result_prob",
#             ]
#         }
#
#         ---
#         Company name to find:
#         Cofinimmo
#         ---
#         List of companies:
#         KeyCorp
# Summit Materials, Inc.
# Gibson Energy Inc.
# HCW Biologics Inc.
# Essential Metals Limited
# EVI Industries, Inc.
# Koenig & Bauer AG
# Microchip Technology Incorporated
# Corbus Pharmaceuticals Holdings, Inc.
# Audalia Resources Limited
# Enerflex Ltd.
# MFA Financial, Inc.
# Strike Resources Limited
# Altech Chemicals Ltd
# HV Bancorp, Inc.
# Zymeworks Inc.
# iBio, Inc.
# Winnebago Industries, Inc.
# Terns Pharmaceuticals, Inc.
# Canadian Tire Corporation
# Prodigy Gold NL
# Alien Metals Limited
# Urban Logistics REIT plc
# Xero Limited
# Dunedin Enterprise Investment Trust PLC
# Cofinimmo
# Maxeon Solar Technologies, Ltd.
# Hagerty, Inc.
# Universal Electronics Inc.
# Lipocine Inc.
# ICICI Bank
# CareTrust REIT, Inc.
# Charles & Colvard, Ltd.
# Renold plc
# LVMH
# Advantage Solutions Inc.
# Harworth Group plc
# Johns Lyng Group Limited
# Nevro Corp.
# Ameresco, Inc.
# 2025-02-24T22:06:22 | INFO | model_answers=
# [{'result_name': 'Cofinimmo', 'result_list_position': '26', 'result_prob': 1.0}, {'result_name': 'Cofinimmo', 'result_list_position': '26', 'result_prob': 1.0}, {'result_name': 'Cofinimmo', 'result_list_position': '26', 'result_prob': 1.0}]
# 2025-02-24T22:06:22 | INFO | subset_documents_to_look_through=[25]
#  10%|█         | 3/30 [01:53<17:37, 39.18s/it]2025-02-24T22:06:22 | INFO |  10%|█         | 3/30 [01:53<17:37, 39.18s/it]
# 2025-02-24T22:06:22 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
#     The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#     The output is a JSON that corresponds to the following schema:
#     {
#         "type": "object",
#         "properties": {
#             "result": {
#                 "description": "One company name",
#                 "type": "array",
#                 "items": {
#                     "type": "string"
#                 }
#             },
#             "result_prob": {
#                 "description": "Probability that the result is the right one. Float from 0 to 1.",
#                 "type": "number"
#             }
#         },
#         "required": [
#             "result",
#             "result_prob",
#         ]
#     }
#
#     ---
#     Question:
#     What is the total number of employees let go by Hagerty, Inc. according to the annual report? If data is not available, return 'N/A'.
#
# 2025-02-24T22:06:30 | INFO | model_answers=
# [{'result': ['Hagerty, Inc.'], 'result_prob': 1.0}, {'result': ['Hagerty, Inc.'], 'result_prob': 1.0}, {'result': ['Hagerty, Inc.'], 'result_prob': 1.0}]
# 2025-02-24T22:06:30 | INFO | list_companies=['Hagerty, Inc.']
# 2025-02-24T22:06:30 | INFO | msg=
# Find this company name in the following list.
#         ---
#         Output format:
#         The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#         The output is a JSON that corresponds to the following schema:
#         {
#             "type": "object",
#             "properties": {
#                 "result_name": {
#                     "description": "The company name found in list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_list_position": {
#                     "description": "The position of the found company in a list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_prob": {
#                     "description": "Probability that the result is the right one. Float from 0 to 1.",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "result",
#                 "result_list_position",
#                 "result_prob",
#             ]
#         }
#
#         ---
#         Company name to find:
#         Hagerty, Inc.
#         ---
#         List of companies:
#         KeyCorp
# Summit Materials, Inc.
# Gibson Energy Inc.
# HCW Biologics Inc.
# Essential Metals Limited
# EVI Industries, Inc.
# Koenig & Bauer AG
# Microchip Technology Incorporated
# Corbus Pharmaceuticals Holdings, Inc.
# Audalia Resources Limited
# Enerflex Ltd.
# MFA Financial, Inc.
# Strike Resources Limited
# Altech Chemicals Ltd
# HV Bancorp, Inc.
# Zymeworks Inc.
# iBio, Inc.
# Winnebago Industries, Inc.
# Terns Pharmaceuticals, Inc.
# Canadian Tire Corporation
# Prodigy Gold NL
# Alien Metals Limited
# Urban Logistics REIT plc
# Xero Limited
# Dunedin Enterprise Investment Trust PLC
# Cofinimmo
# Maxeon Solar Technologies, Ltd.
# Hagerty, Inc.
# Universal Electronics Inc.
# Lipocine Inc.
# ICICI Bank
# CareTrust REIT, Inc.
# Charles & Colvard, Ltd.
# Renold plc
# LVMH
# Advantage Solutions Inc.
# Harworth Group plc
# Johns Lyng Group Limited
# Nevro Corp.
# Ameresco, Inc.
# 2025-02-24T22:06:56 | INFO | model_answers=
# [{'result_name': 'Hagerty, Inc.', 'result_list_position': '28', 'result_prob': 1.0}, {'result_name': 'Hagerty, Inc.', 'result_list_position': '28', 'result_prob': 1.0}, {'result_name': 'Hagerty, Inc.', 'result_list_position': '28', 'result_prob': 1.0}]
# 2025-02-24T22:06:56 | INFO | subset_documents_to_look_through=[27]
#  13%|█▎        | 4/30 [02:28<16:11, 37.36s/it]2025-02-24T22:06:56 | INFO |  13%|█▎        | 4/30 [02:28<16:11, 37.36s/it]
# 2025-02-24T22:06:56 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
#     The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#     The output is a JSON that corresponds to the following schema:
#     {
#         "type": "object",
#         "properties": {
#             "result": {
#                 "description": "One company name",
#                 "type": "array",
#                 "items": {
#                     "type": "string"
#                 }
#             },
#             "result_prob": {
#                 "description": "Probability that the result is the right one. Float from 0 to 1.",
#                 "type": "number"
#             }
#         },
#         "required": [
#             "result",
#             "result_prob",
#         ]
#     }
#
#     ---
#     Question:
#     Which leadership **positions** changed at Renold plc in the reporting period? If data is not available, return 'N/A'.
#
# 2025-02-24T22:07:05 | INFO | model_answers=
# [{'result': ['Renold plc'], 'result_prob': 1.0}, {'result': ['Renold plc'], 'result_prob': 0.99}, {'result': ['Renold plc'], 'result_prob': 1.0}]
# 2025-02-24T22:07:05 | INFO | list_companies=['Renold plc']
# 2025-02-24T22:07:05 | INFO | msg=
# Find this company name in the following list.
#         ---
#         Output format:
#         The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#         The output is a JSON that corresponds to the following schema:
#         {
#             "type": "object",
#             "properties": {
#                 "result_name": {
#                     "description": "The company name found in list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_list_position": {
#                     "description": "The position of the found company in a list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_prob": {
#                     "description": "Probability that the result is the right one. Float from 0 to 1.",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "result",
#                 "result_list_position",
#                 "result_prob",
#             ]
#         }
#
#         ---
#         Company name to find:
#         Renold plc
#         ---
#         List of companies:
#         KeyCorp
# Summit Materials, Inc.
# Gibson Energy Inc.
# HCW Biologics Inc.
# Essential Metals Limited
# EVI Industries, Inc.
# Koenig & Bauer AG
# Microchip Technology Incorporated
# Corbus Pharmaceuticals Holdings, Inc.
# Audalia Resources Limited
# Enerflex Ltd.
# MFA Financial, Inc.
# Strike Resources Limited
# Altech Chemicals Ltd
# HV Bancorp, Inc.
# Zymeworks Inc.
# iBio, Inc.
# Winnebago Industries, Inc.
# Terns Pharmaceuticals, Inc.
# Canadian Tire Corporation
# Prodigy Gold NL
# Alien Metals Limited
# Urban Logistics REIT plc
# Xero Limited
# Dunedin Enterprise Investment Trust PLC
# Cofinimmo
# Maxeon Solar Technologies, Ltd.
# Hagerty, Inc.
# Universal Electronics Inc.
# Lipocine Inc.
# ICICI Bank
# CareTrust REIT, Inc.
# Charles & Colvard, Ltd.
# Renold plc
# LVMH
# Advantage Solutions Inc.
# Harworth Group plc
# Johns Lyng Group Limited
# Nevro Corp.
# Ameresco, Inc.
# 2025-02-24T22:07:26 | INFO | model_answers=
# [{'result_name': 'Renold plc', 'result_list_position': '34', 'result_prob': 1.0}, {'result_name': 'Renold plc', 'result_list_position': '34', 'result_prob': 1.0}, {'result_name': 'Renold plc', 'result_list_position': '34', 'result_prob': 1.0}]
# 2025-02-24T22:07:26 | INFO | subset_documents_to_look_through=[33]
#  17%|█▋        | 5/30 [02:58<14:23, 34.52s/it]2025-02-24T22:07:26 | INFO |  17%|█▋        | 5/30 [02:58<14:23, 34.52s/it]
# 2025-02-24T22:07:26 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
#     The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#     The output is a JSON that corresponds to the following schema:
#     {
#         "type": "object",
#         "properties": {
#             "result": {
#                 "description": "One company name",
#                 "type": "array",
#                 "items": {
#                     "type": "string"
#                 }
#             },
#             "result_prob": {
#                 "description": "Probability that the result is the right one. Float from 0 to 1.",
#                 "type": "number"
#             }
#         },
#         "required": [
#             "result",
#             "result_prob",
#         ]
#     }
#
#     ---
#     Question:
#     What was the Gross margin (%) for Charles & Colvard, Ltd. according to the annual report (within the last period or at the end of the last period)? If data is not available, return 'N/A'.
#
# 2025-02-24T22:07:36 | INFO | model_answers=
# [{'result': ['Charles & Colvard, Ltd.'], 'result_prob': 1.0}, {'result': ['Charles & Colvard, Ltd.'], 'result_prob': 0.95}, {'result': ['Charles & Colvard, Ltd.'], 'result_prob': 0.99}]
# 2025-02-24T22:07:36 | INFO | list_companies=['Charles & Colvard, Ltd.']
# 2025-02-24T22:07:36 | INFO | msg=
# Find this company name in the following list.
#         ---
#         Output format:
#         The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#         The output is a JSON that corresponds to the following schema:
#         {
#             "type": "object",
#             "properties": {
#                 "result_name": {
#                     "description": "The company name found in list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_list_position": {
#                     "description": "The position of the found company in a list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_prob": {
#                     "description": "Probability that the result is the right one. Float from 0 to 1.",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "result",
#                 "result_list_position",
#                 "result_prob",
#             ]
#         }
#
#         ---
#         Company name to find:
#         Charles & Colvard, Ltd.
#         ---
#         List of companies:
#         KeyCorp
# Summit Materials, Inc.
# Gibson Energy Inc.
# HCW Biologics Inc.
# Essential Metals Limited
# EVI Industries, Inc.
# Koenig & Bauer AG
# Microchip Technology Incorporated
# Corbus Pharmaceuticals Holdings, Inc.
# Audalia Resources Limited
# Enerflex Ltd.
# MFA Financial, Inc.
# Strike Resources Limited
# Altech Chemicals Ltd
# HV Bancorp, Inc.
# Zymeworks Inc.
# iBio, Inc.
# Winnebago Industries, Inc.
# Terns Pharmaceuticals, Inc.
# Canadian Tire Corporation
# Prodigy Gold NL
# Alien Metals Limited
# Urban Logistics REIT plc
# Xero Limited
# Dunedin Enterprise Investment Trust PLC
# Cofinimmo
# Maxeon Solar Technologies, Ltd.
# Hagerty, Inc.
# Universal Electronics Inc.
# Lipocine Inc.
# ICICI Bank
# CareTrust REIT, Inc.
# Charles & Colvard, Ltd.
# Renold plc
# LVMH
# Advantage Solutions Inc.
# Harworth Group plc
# Johns Lyng Group Limited
# Nevro Corp.
# Ameresco, Inc.
# 2025-02-24T22:08:05 | INFO | model_answers=
# [{'result_name': 'Charles & Colvard, Ltd.', 'result_list_position': '33', 'result_prob': 1.0}, {'result_name': 'Charles & Colvard, Ltd.', 'result_list_position': '33', 'result_prob': 1.0}, {'result_name': 'Charles & Colvard, Ltd.', 'result_list_position': '33', 'result_prob': 1.0}]
# 2025-02-24T22:08:05 | INFO | subset_documents_to_look_through=[32]
#  20%|██        | 6/30 [03:37<14:31, 36.31s/it]2025-02-24T22:08:05 | INFO |  20%|██        | 6/30 [03:37<14:31, 36.31s/it]
# 2025-02-24T22:08:05 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
#     The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#     The output is a JSON that corresponds to the following schema:
#     {
#         "type": "object",
#         "properties": {
#             "result": {
#                 "description": "One company name",
#                 "type": "array",
#                 "items": {
#                     "type": "string"
#                 }
#             },
#             "result_prob": {
#                 "description": "Probability that the result is the right one. Float from 0 to 1.",
#                 "type": "number"
#             }
#         },
#         "required": [
#             "result",
#             "result_prob",
#         ]
#     }
#
#     ---
#     Question:
#     What was the Capital expenditures (in GBP) for Harworth Group plc according to the annual report (within the last period or at the end of the last period)? If data is not available, return 'N/A'.
#
# 2025-02-24T22:08:22 | INFO | model_answers=
# [{'result': ['Harworth Group plc'], 'result_prob': 1.0}, {'result': ['Harworth Group plc'], 'result_prob': 1.0}, {'result': ['Harworth Group plc'], 'result_prob': 1.0}]
# 2025-02-24T22:08:22 | INFO | list_companies=['Harworth Group plc']
# 2025-02-24T22:08:22 | INFO | msg=
# Find this company name in the following list.
#         ---
#         Output format:
#         The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#         The output is a JSON that corresponds to the following schema:
#         {
#             "type": "object",
#             "properties": {
#                 "result_name": {
#                     "description": "The company name found in list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_list_position": {
#                     "description": "The position of the found company in a list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_prob": {
#                     "description": "Probability that the result is the right one. Float from 0 to 1.",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "result",
#                 "result_list_position",
#                 "result_prob",
#             ]
#         }
#
#         ---
#         Company name to find:
#         Harworth Group plc
#         ---
#         List of companies:
#         KeyCorp
# Summit Materials, Inc.
# Gibson Energy Inc.
# HCW Biologics Inc.
# Essential Metals Limited
# EVI Industries, Inc.
# Koenig & Bauer AG
# Microchip Technology Incorporated
# Corbus Pharmaceuticals Holdings, Inc.
# Audalia Resources Limited
# Enerflex Ltd.
# MFA Financial, Inc.
# Strike Resources Limited
# Altech Chemicals Ltd
# HV Bancorp, Inc.
# Zymeworks Inc.
# iBio, Inc.
# Winnebago Industries, Inc.
# Terns Pharmaceuticals, Inc.
# Canadian Tire Corporation
# Prodigy Gold NL
# Alien Metals Limited
# Urban Logistics REIT plc
# Xero Limited
# Dunedin Enterprise Investment Trust PLC
# Cofinimmo
# Maxeon Solar Technologies, Ltd.
# Hagerty, Inc.
# Universal Electronics Inc.
# Lipocine Inc.
# ICICI Bank
# CareTrust REIT, Inc.
# Charles & Colvard, Ltd.
# Renold plc
# LVMH
# Advantage Solutions Inc.
# Harworth Group plc
# Johns Lyng Group Limited
# Nevro Corp.
# Ameresco, Inc.
# 2025-02-24T22:08:48 | INFO | model_answers=
# [{'result_name': 'Harworth Group plc', 'result_list_position': '37', 'result_prob': 1.0}, {'result_name': 'Harworth Group plc', 'result_list_position': '37', 'result_prob': 1.0}, {'result_name': 'Harworth Group plc', 'result_list_position': '37', 'result_prob': 1.0}]
# 2025-02-24T22:08:48 | INFO | subset_documents_to_look_through=[36]
#  23%|██▎       | 7/30 [04:20<14:40, 38.27s/it]2025-02-24T22:08:48 | INFO |  23%|██▎       | 7/30 [04:20<14:40, 38.27s/it]
# 2025-02-24T22:08:48 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
#     The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#     The output is a JSON that corresponds to the following schema:
#     {
#         "type": "object",
#         "properties": {
#             "result": {
#                 "description": "One company name",
#                 "type": "array",
#                 "items": {
#                     "type": "string"
#                 }
#             },
#             "result_prob": {
#                 "description": "Probability that the result is the right one. Float from 0 to 1.",
#                 "type": "number"
#             }
#         },
#         "required": [
#             "result",
#             "result_prob",
#         ]
#     }
#
#     ---
#     Question:
#     What was the Capital expenditures (in USD) for Charles & Colvard, Ltd. according to the annual report (within the last period or at the end of the last period)? If data is not available, return 'N/A'.
#
# 2025-02-24T22:08:58 | INFO | model_answers=
# [{'result': ['Charles & Colvard, Ltd.'], 'result_prob': 1.0}, {'result': ['Charles & Colvard, Ltd.'], 'result_prob': 1.0}, {'result': ['Charles & Colvard, Ltd.'], 'result_prob': 1.0}]
# 2025-02-24T22:08:58 | INFO | list_companies=['Charles & Colvard, Ltd.']
# 2025-02-24T22:08:58 | INFO | msg=
# Find this company name in the following list.
#         ---
#         Output format:
#         The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#         The output is a JSON that corresponds to the following schema:
#         {
#             "type": "object",
#             "properties": {
#                 "result_name": {
#                     "description": "The company name found in list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_list_position": {
#                     "description": "The position of the found company in a list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_prob": {
#                     "description": "Probability that the result is the right one. Float from 0 to 1.",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "result",
#                 "result_list_position",
#                 "result_prob",
#             ]
#         }
#
#         ---
#         Company name to find:
#         Charles & Colvard, Ltd.
#         ---
#         List of companies:
#         KeyCorp
# Summit Materials, Inc.
# Gibson Energy Inc.
# HCW Biologics Inc.
# Essential Metals Limited
# EVI Industries, Inc.
# Koenig & Bauer AG
# Microchip Technology Incorporated
# Corbus Pharmaceuticals Holdings, Inc.
# Audalia Resources Limited
# Enerflex Ltd.
# MFA Financial, Inc.
# Strike Resources Limited
# Altech Chemicals Ltd
# HV Bancorp, Inc.
# Zymeworks Inc.
# iBio, Inc.
# Winnebago Industries, Inc.
# Terns Pharmaceuticals, Inc.
# Canadian Tire Corporation
# Prodigy Gold NL
# Alien Metals Limited
# Urban Logistics REIT plc
# Xero Limited
# Dunedin Enterprise Investment Trust PLC
# Cofinimmo
# Maxeon Solar Technologies, Ltd.
# Hagerty, Inc.
# Universal Electronics Inc.
# Lipocine Inc.
# ICICI Bank
# CareTrust REIT, Inc.
# Charles & Colvard, Ltd.
# Renold plc
# LVMH
# Advantage Solutions Inc.
# Harworth Group plc
# Johns Lyng Group Limited
# Nevro Corp.
# Ameresco, Inc.
# 2025-02-24T22:09:30 | INFO | model_answers=
# [{'result_name': 'Charles & Colvard, Ltd.', 'result_list_position': '33', 'result_prob': 1}, {'result_name': 'Charles & Colvard, Ltd.', 'result_list_position': '33', 'result_prob': 1.0}, {'result_name': 'Charles & Colvard, Ltd.', 'result_list_position': '33', 'result_prob': 1.0}]
# 2025-02-24T22:09:30 | INFO | subset_documents_to_look_through=[32]
#  27%|██▋       | 8/30 [05:02<14:31, 39.60s/it]2025-02-24T22:09:30 | INFO |  27%|██▋       | 8/30 [05:02<14:31, 39.60s/it]
# 2025-02-24T22:09:30 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
#     The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#     The output is a JSON that corresponds to the following schema:
#     {
#         "type": "object",
#         "properties": {
#             "result": {
#                 "description": "One company name",
#                 "type": "array",
#                 "items": {
#                     "type": "string"
#                 }
#             },
#             "result_prob": {
#                 "description": "Probability that the result is the right one. Float from 0 to 1.",
#                 "type": "number"
#             }
#         },
#         "required": [
#             "result",
#             "result_prob",
#         ]
#     }
#
#     ---
#     Question:
#     What are the names of new products launched by Zymeworks Inc. as mentioned in the annual report?
#
# 2025-02-24T22:09:39 | INFO | model_answers=
# [{'result': ['Zymeworks Inc.'], 'result_prob': 1.0}, {'result': ['Zymeworks Inc.'], 'result_prob': 1.0}, {'result': ['Zymeworks Inc.'], 'result_prob': 0.99}]
# 2025-02-24T22:09:39 | INFO | list_companies=['Zymeworks Inc.']
# 2025-02-24T22:09:39 | INFO | msg=
# Find this company name in the following list.
#         ---
#         Output format:
#         The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#         The output is a JSON that corresponds to the following schema:
#         {
#             "type": "object",
#             "properties": {
#                 "result_name": {
#                     "description": "The company name found in list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_list_position": {
#                     "description": "The position of the found company in a list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_prob": {
#                     "description": "Probability that the result is the right one. Float from 0 to 1.",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "result",
#                 "result_list_position",
#                 "result_prob",
#             ]
#         }
#
#         ---
#         Company name to find:
#         Zymeworks Inc.
#         ---
#         List of companies:
#         KeyCorp
# Summit Materials, Inc.
# Gibson Energy Inc.
# HCW Biologics Inc.
# Essential Metals Limited
# EVI Industries, Inc.
# Koenig & Bauer AG
# Microchip Technology Incorporated
# Corbus Pharmaceuticals Holdings, Inc.
# Audalia Resources Limited
# Enerflex Ltd.
# MFA Financial, Inc.
# Strike Resources Limited
# Altech Chemicals Ltd
# HV Bancorp, Inc.
# Zymeworks Inc.
# iBio, Inc.
# Winnebago Industries, Inc.
# Terns Pharmaceuticals, Inc.
# Canadian Tire Corporation
# Prodigy Gold NL
# Alien Metals Limited
# Urban Logistics REIT plc
# Xero Limited
# Dunedin Enterprise Investment Trust PLC
# Cofinimmo
# Maxeon Solar Technologies, Ltd.
# Hagerty, Inc.
# Universal Electronics Inc.
# Lipocine Inc.
# ICICI Bank
# CareTrust REIT, Inc.
# Charles & Colvard, Ltd.
# Renold plc
# LVMH
# Advantage Solutions Inc.
# Harworth Group plc
# Johns Lyng Group Limited
# Nevro Corp.
# Ameresco, Inc.
# 2025-02-24T22:10:10 | INFO | model_answers=
# [{'result_name': 'Zymeworks Inc.', 'result_list_position': '16', 'result_prob': 1.0}, {'result_name': 'Zymeworks Inc.', 'result_list_position': '16', 'result_prob': 1.0}, {'result_name': 'Zymeworks Inc.', 'result_list_position': '16', 'result_prob': 1.0}]
# 2025-02-24T22:10:10 | INFO | subset_documents_to_look_through=[15]
#  30%|███       | 9/30 [05:41<13:49, 39.50s/it]2025-02-24T22:10:10 | INFO |  30%|███       | 9/30 [05:41<13:49, 39.50s/it]
# 2025-02-24T22:10:10 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
#     The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#     The output is a JSON that corresponds to the following schema:
#     {
#         "type": "object",
#         "properties": {
#             "result": {
#                 "description": "One company name",
#                 "type": "array",
#                 "items": {
#                     "type": "string"
#                 }
#             },
#             "result_prob": {
#                 "description": "Probability that the result is the right one. Float from 0 to 1.",
#                 "type": "number"
#             }
#         },
#         "required": [
#             "result",
#             "result_prob",
#         ]
#     }
#
#     ---
#     Question:
#     For Lipocine Inc., what was the value of Number of diagnostic centers at year-end at the end of the period listed in annual report? If data is not available, return 'N/A'.
#
# 2025-02-24T22:10:16 | INFO | model_answers=
# [{'result': ['Lipocine Inc.'], 'result_prob': 1.0}, {'result': ['Lipocine Inc.'], 'result_prob': 0.99}, {'result': ['Lipocine Inc.'], 'result_prob': 1.0}]
# 2025-02-24T22:10:16 | INFO | list_companies=['Lipocine Inc.']
# 2025-02-24T22:10:17 | INFO | msg=
# Find this company name in the following list.
#         ---
#         Output format:
#         The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#         The output is a JSON that corresponds to the following schema:
#         {
#             "type": "object",
#             "properties": {
#                 "result_name": {
#                     "description": "The company name found in list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_list_position": {
#                     "description": "The position of the found company in a list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_prob": {
#                     "description": "Probability that the result is the right one. Float from 0 to 1.",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "result",
#                 "result_list_position",
#                 "result_prob",
#             ]
#         }
#
#         ---
#         Company name to find:
#         Lipocine Inc.
#         ---
#         List of companies:
#         KeyCorp
# Summit Materials, Inc.
# Gibson Energy Inc.
# HCW Biologics Inc.
# Essential Metals Limited
# EVI Industries, Inc.
# Koenig & Bauer AG
# Microchip Technology Incorporated
# Corbus Pharmaceuticals Holdings, Inc.
# Audalia Resources Limited
# Enerflex Ltd.
# MFA Financial, Inc.
# Strike Resources Limited
# Altech Chemicals Ltd
# HV Bancorp, Inc.
# Zymeworks Inc.
# iBio, Inc.
# Winnebago Industries, Inc.
# Terns Pharmaceuticals, Inc.
# Canadian Tire Corporation
# Prodigy Gold NL
# Alien Metals Limited
# Urban Logistics REIT plc
# Xero Limited
# Dunedin Enterprise Investment Trust PLC
# Cofinimmo
# Maxeon Solar Technologies, Ltd.
# Hagerty, Inc.
# Universal Electronics Inc.
# Lipocine Inc.
# ICICI Bank
# CareTrust REIT, Inc.
# Charles & Colvard, Ltd.
# Renold plc
# LVMH
# Advantage Solutions Inc.
# Harworth Group plc
# Johns Lyng Group Limited
# Nevro Corp.
# Ameresco, Inc.
# 2025-02-24T22:10:40 | INFO | model_answers=
# [{'result_name': 'Lipocine Inc.', 'result_list_position': '30', 'result_prob': 1.0}, {'result_name': 'Lipocine Inc.', 'result_list_position': '30', 'result_prob': 1.0}, {'result_name': 'Lipocine Inc.', 'result_list_position': '30', 'result_prob': 1.0}]
# 2025-02-24T22:10:40 | INFO | subset_documents_to_look_through=[29]
#  33%|███▎      | 10/30 [06:12<12:16, 36.84s/it]2025-02-24T22:10:40 | INFO |  33%|███▎      | 10/30 [06:12<12:16, 36.84s/it]
# 2025-02-24T22:10:40 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
#     The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#     The output is a JSON that corresponds to the following schema:
#     {
#         "type": "object",
#         "properties": {
#             "result": {
#                 "description": "One company name",
#                 "type": "array",
#                 "items": {
#                     "type": "string"
#                 }
#             },
#             "result_prob": {
#                 "description": "Probability that the result is the right one. Float from 0 to 1.",
#                 "type": "number"
#             }
#         },
#         "required": [
#             "result",
#             "result_prob",
#         ]
#     }
#
#     ---
#     Question:
#     According to the annual report, what is the Total revenue (in USD) for Winnebago Industries, Inc.  (within the last period or at the end of the last period)? If data is not available, return 'N/A'.
#
# 2025-02-24T22:10:49 | INFO | model_answers=
# [{'result': ['Winnebago Industries, Inc.'], 'result_prob': 1.0}, {'result': ['Winnebago Industries, Inc.'], 'result_prob': 1.0}, {'result': ['Winnebago Industries, Inc.'], 'result_prob': 1.0}]
# 2025-02-24T22:10:49 | INFO | list_companies=['Winnebago Industries, Inc.']
# 2025-02-24T22:10:49 | INFO | msg=
# Find this company name in the following list.
#         ---
#         Output format:
#         The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#         The output is a JSON that corresponds to the following schema:
#         {
#             "type": "object",
#             "properties": {
#                 "result_name": {
#                     "description": "The company name found in list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_list_position": {
#                     "description": "The position of the found company in a list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_prob": {
#                     "description": "Probability that the result is the right one. Float from 0 to 1.",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "result",
#                 "result_list_position",
#                 "result_prob",
#             ]
#         }
#
#         ---
#         Company name to find:
#         Winnebago Industries, Inc.
#         ---
#         List of companies:
#         KeyCorp
# Summit Materials, Inc.
# Gibson Energy Inc.
# HCW Biologics Inc.
# Essential Metals Limited
# EVI Industries, Inc.
# Koenig & Bauer AG
# Microchip Technology Incorporated
# Corbus Pharmaceuticals Holdings, Inc.
# Audalia Resources Limited
# Enerflex Ltd.
# MFA Financial, Inc.
# Strike Resources Limited
# Altech Chemicals Ltd
# HV Bancorp, Inc.
# Zymeworks Inc.
# iBio, Inc.
# Winnebago Industries, Inc.
# Terns Pharmaceuticals, Inc.
# Canadian Tire Corporation
# Prodigy Gold NL
# Alien Metals Limited
# Urban Logistics REIT plc
# Xero Limited
# Dunedin Enterprise Investment Trust PLC
# Cofinimmo
# Maxeon Solar Technologies, Ltd.
# Hagerty, Inc.
# Universal Electronics Inc.
# Lipocine Inc.
# ICICI Bank
# CareTrust REIT, Inc.
# Charles & Colvard, Ltd.
# Renold plc
# LVMH
# Advantage Solutions Inc.
# Harworth Group plc
# Johns Lyng Group Limited
# Nevro Corp.
# Ameresco, Inc.
# 2025-02-24T22:11:19 | INFO | model_answers=
# [{'result_name': 'Winnebago Industries, Inc.', 'result_list_position': '18', 'result_prob': 1}, {'result_name': 'Winnebago Industries, Inc.', 'result_list_position': '18', 'result_prob': 1.0}, {'result_name': 'Winnebago Industries, Inc.', 'result_list_position': '18', 'result_prob': 1.0}]
# 2025-02-24T22:11:19 | INFO | subset_documents_to_look_through=[17]
#  37%|███▋      | 11/30 [06:50<11:47, 37.25s/it]2025-02-24T22:11:19 | INFO |  37%|███▋      | 11/30 [06:50<11:47, 37.25s/it]
# 2025-02-24T22:11:19 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
#     The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#     The output is a JSON that corresponds to the following schema:
#     {
#         "type": "object",
#         "properties": {
#             "result": {
#                 "description": "One company name",
#                 "type": "array",
#                 "items": {
#                     "type": "string"
#                 }
#             },
#             "result_prob": {
#                 "description": "Probability that the result is the right one. Float from 0 to 1.",
#                 "type": "number"
#             }
#         },
#         "required": [
#             "result",
#             "result_prob",
#         ]
#     }
#
#     ---
#     Question:
#     For Lipocine Inc., what was the value of Value of medical equipment (balance sheet) at the end of the period listed in annual report? If data is not available, return 'N/A'.
#
# 2025-02-24T22:11:28 | INFO | model_answers=
# [{'result': ['Lipocine Inc.'], 'result_prob': 1.0}, {'result': ['Lipocine Inc.'], 'result_prob': 1.0}, {'result': ['Lipocine Inc.'], 'result_prob': 1.0}]
# 2025-02-24T22:11:28 | INFO | list_companies=['Lipocine Inc.']
# 2025-02-24T22:11:29 | INFO | msg=
# Find this company name in the following list.
#         ---
#         Output format:
#         The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#         The output is a JSON that corresponds to the following schema:
#         {
#             "type": "object",
#             "properties": {
#                 "result_name": {
#                     "description": "The company name found in list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_list_position": {
#                     "description": "The position of the found company in a list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_prob": {
#                     "description": "Probability that the result is the right one. Float from 0 to 1.",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "result",
#                 "result_list_position",
#                 "result_prob",
#             ]
#         }
#
#         ---
#         Company name to find:
#         Lipocine Inc.
#         ---
#         List of companies:
#         KeyCorp
# Summit Materials, Inc.
# Gibson Energy Inc.
# HCW Biologics Inc.
# Essential Metals Limited
# EVI Industries, Inc.
# Koenig & Bauer AG
# Microchip Technology Incorporated
# Corbus Pharmaceuticals Holdings, Inc.
# Audalia Resources Limited
# Enerflex Ltd.
# MFA Financial, Inc.
# Strike Resources Limited
# Altech Chemicals Ltd
# HV Bancorp, Inc.
# Zymeworks Inc.
# iBio, Inc.
# Winnebago Industries, Inc.
# Terns Pharmaceuticals, Inc.
# Canadian Tire Corporation
# Prodigy Gold NL
# Alien Metals Limited
# Urban Logistics REIT plc
# Xero Limited
# Dunedin Enterprise Investment Trust PLC
# Cofinimmo
# Maxeon Solar Technologies, Ltd.
# Hagerty, Inc.
# Universal Electronics Inc.
# Lipocine Inc.
# ICICI Bank
# CareTrust REIT, Inc.
# Charles & Colvard, Ltd.
# Renold plc
# LVMH
# Advantage Solutions Inc.
# Harworth Group plc
# Johns Lyng Group Limited
# Nevro Corp.
# Ameresco, Inc.
# 2025-02-24T22:11:51 | INFO | model_answers=
# [{'result_name': 'Lipocine Inc.', 'result_list_position': '30', 'result_prob': 1.0}, {'result_name': 'Lipocine Inc.', 'result_list_position': '30', 'result_prob': 1.0}, {'result_name': 'Lipocine Inc.', 'result_list_position': '30', 'result_prob': 1.0}]
# 2025-02-24T22:11:51 | INFO | subset_documents_to_look_through=[29]
#  40%|████      | 12/30 [07:23<10:44, 35.82s/it]2025-02-24T22:11:51 | INFO |  40%|████      | 12/30 [07:23<10:44, 35.82s/it]
# 2025-02-24T22:11:51 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
# ...
#  87%|████████▋ | 26/30 [16:55<02:57, 44.37s/it]2025-02-24T22:21:23 | INFO |  87%|████████▋ | 26/30 [16:55<02:57, 44.37s/it]
# 2025-02-24T22:21:23 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
#     The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#     The output is a JSON that corresponds to the following schema:
#     {
#         "type": "object",
#         "properties": {
#             "result": {
#                 "description": "One company name",
#                 "type": "array",
#                 "items": {
#                     "type": "string"
#                 }
#             },
#             "result_prob": {
#                 "description": "Probability that the result is the right one. Float from 0 to 1.",
#                 "type": "number"
#             }
#         },
#         "required": [
#             "result",
#             "result_prob",
#         ]
#     }
#
#     ---
#     Question:
#     Did Cofinimmo announce any changes to its dividend policy in the annual report?
#
# 2025-02-24T22:21:41 | INFO | model_answers=
# [{'result': ['Cofinimmo'], 'result_prob': 1.0}, {'result': ['Cofinimmo'], 'result_prob': 0.99}, {'result': ['Cofinimmo'], 'result_prob': 1.0}]
# 2025-02-24T22:21:41 | INFO | list_companies=['Cofinimmo']
# 2025-02-24T22:21:41 | INFO | msg=
# Find this company name in the following list.
#         ---
#         Output format:
#         The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#         The output is a JSON that corresponds to the following schema:
#         {
#             "type": "object",
#             "properties": {
#                 "result_name": {
#                     "description": "The company name found in list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_list_position": {
#                     "description": "The position of the found company in a list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_prob": {
#                     "description": "Probability that the result is the right one. Float from 0 to 1.",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "result",
#                 "result_list_position",
#                 "result_prob",
#             ]
#         }
#
#         ---
#         Company name to find:
#         Cofinimmo
#         ---
#         List of companies:
#         KeyCorp
# Summit Materials, Inc.
# Gibson Energy Inc.
# HCW Biologics Inc.
# Essential Metals Limited
# EVI Industries, Inc.
# Koenig & Bauer AG
# Microchip Technology Incorporated
# Corbus Pharmaceuticals Holdings, Inc.
# Audalia Resources Limited
# Enerflex Ltd.
# MFA Financial, Inc.
# Strike Resources Limited
# Altech Chemicals Ltd
# HV Bancorp, Inc.
# Zymeworks Inc.
# iBio, Inc.
# Winnebago Industries, Inc.
# Terns Pharmaceuticals, Inc.
# Canadian Tire Corporation
# Prodigy Gold NL
# Alien Metals Limited
# Urban Logistics REIT plc
# Xero Limited
# Dunedin Enterprise Investment Trust PLC
# Cofinimmo
# Maxeon Solar Technologies, Ltd.
# Hagerty, Inc.
# Universal Electronics Inc.
# Lipocine Inc.
# ICICI Bank
# CareTrust REIT, Inc.
# Charles & Colvard, Ltd.
# Renold plc
# LVMH
# Advantage Solutions Inc.
# Harworth Group plc
# Johns Lyng Group Limited
# Nevro Corp.
# Ameresco, Inc.
# 2025-02-24T22:21:59 | INFO | model_answers=
# [{'result_name': 'Cofinimmo', 'result_list_position': '26', 'result_prob': 1.0}, {'result_name': 'Cofinimmo', 'result_list_position': '26', 'result_prob': 1.0}, {'result_name': 'Cofinimmo', 'result_list_position': '26', 'result_prob': 1.0}]
# 2025-02-24T22:21:59 | INFO | subset_documents_to_look_through=[25]
#  90%|█████████ | 27/30 [17:31<02:05, 41.80s/it]2025-02-24T22:21:59 | INFO |  90%|█████████ | 27/30 [17:31<02:05, 41.80s/it]
# 2025-02-24T22:21:59 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
#     The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#     The output is a JSON that corresponds to the following schema:
#     {
#         "type": "object",
#         "properties": {
#             "result": {
#                 "description": "One company name",
#                 "type": "array",
#                 "items": {
#                     "type": "string"
#                 }
#             },
#             "result_prob": {
#                 "description": "Probability that the result is the right one. Float from 0 to 1.",
#                 "type": "number"
#             }
#         },
#         "required": [
#             "result",
#             "result_prob",
#         ]
#     }
#
#     ---
#     Question:
#     What was the value of Distribution network length of Maxeon Solar Technologies, Ltd. at the end of the period listed in annual report? If data is not available, return 'N/A'.
#
# 2025-02-24T22:22:10 | INFO | model_answers=
# [{'result': ['Maxeon Solar Technologies, Ltd.'], 'result_prob': 1.0}, {'result': ['Maxeon Solar Technologies, Ltd.'], 'result_prob': 1.0}, {'result': ['Maxeon Solar Technologies, Ltd.'], 'result_prob': 1.0}]
# 2025-02-24T22:22:10 | INFO | list_companies=['Maxeon Solar Technologies, Ltd.']
# 2025-02-24T22:22:10 | INFO | msg=
# Find this company name in the following list.
#         ---
#         Output format:
#         The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#         The output is a JSON that corresponds to the following schema:
#         {
#             "type": "object",
#             "properties": {
#                 "result_name": {
#                     "description": "The company name found in list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_list_position": {
#                     "description": "The position of the found company in a list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_prob": {
#                     "description": "Probability that the result is the right one. Float from 0 to 1.",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "result",
#                 "result_list_position",
#                 "result_prob",
#             ]
#         }
#
#         ---
#         Company name to find:
#         Maxeon Solar Technologies, Ltd.
#         ---
#         List of companies:
#         KeyCorp
# Summit Materials, Inc.
# Gibson Energy Inc.
# HCW Biologics Inc.
# Essential Metals Limited
# EVI Industries, Inc.
# Koenig & Bauer AG
# Microchip Technology Incorporated
# Corbus Pharmaceuticals Holdings, Inc.
# Audalia Resources Limited
# Enerflex Ltd.
# MFA Financial, Inc.
# Strike Resources Limited
# Altech Chemicals Ltd
# HV Bancorp, Inc.
# Zymeworks Inc.
# iBio, Inc.
# Winnebago Industries, Inc.
# Terns Pharmaceuticals, Inc.
# Canadian Tire Corporation
# Prodigy Gold NL
# Alien Metals Limited
# Urban Logistics REIT plc
# Xero Limited
# Dunedin Enterprise Investment Trust PLC
# Cofinimmo
# Maxeon Solar Technologies, Ltd.
# Hagerty, Inc.
# Universal Electronics Inc.
# Lipocine Inc.
# ICICI Bank
# CareTrust REIT, Inc.
# Charles & Colvard, Ltd.
# Renold plc
# LVMH
# Advantage Solutions Inc.
# Harworth Group plc
# Johns Lyng Group Limited
# Nevro Corp.
# Ameresco, Inc.
# 2025-02-24T22:22:31 | INFO | model_answers=
# [{'result_name': 'Maxeon Solar Technologies, Ltd.', 'result_list_position': '27', 'result_prob': 1.0}, {'result_name': 'Maxeon Solar Technologies, Ltd.', 'result_list_position': '27', 'result_prob': 1.0}, {'result_name': 'Maxeon Solar Technologies, Ltd.', 'result_list_position': '27', 'result_prob': 1.0}]
# 2025-02-24T22:22:31 | INFO | subset_documents_to_look_through=[26]
#  93%|█████████▎| 28/30 [18:03<01:17, 38.79s/it]2025-02-24T22:22:31 | INFO |  93%|█████████▎| 28/30 [18:03<01:17, 38.79s/it]
# 2025-02-24T22:22:31 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
#     The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#     The output is a JSON that corresponds to the following schema:
#     {
#         "type": "object",
#         "properties": {
#             "result": {
#                 "description": "One company name",
#                 "type": "array",
#                 "items": {
#                     "type": "string"
#                 }
#             },
#             "result_prob": {
#                 "description": "Probability that the result is the right one. Float from 0 to 1.",
#                 "type": "number"
#             }
#         },
#         "required": [
#             "result",
#             "result_prob",
#         ]
#     }
#
#     ---
#     Question:
#     What was the value of Healthcare plan memberships (if applicable) of Nevro Corp. at the end of the period listed in annual report? If data is not available, return 'N/A'.
#
# 2025-02-24T22:22:45 | INFO | model_answers=
# [{'result': ['Nevro Corp.'], 'result_prob': 0.99}, {'result': ['Nevro Corp.'], 'result_prob': 1.0}, {'result': ['Nevro Corp.'], 'result_prob': 1.0}]
# 2025-02-24T22:22:45 | INFO | list_companies=['Nevro Corp.']
# 2025-02-24T22:22:45 | INFO | msg=
# Find this company name in the following list.
#         ---
#         Output format:
#         The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#         The output is a JSON that corresponds to the following schema:
#         {
#             "type": "object",
#             "properties": {
#                 "result_name": {
#                     "description": "The company name found in list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_list_position": {
#                     "description": "The position of the found company in a list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_prob": {
#                     "description": "Probability that the result is the right one. Float from 0 to 1.",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "result",
#                 "result_list_position",
#                 "result_prob",
#             ]
#         }
#
#         ---
#         Company name to find:
#         Nevro Corp.
#         ---
#         List of companies:
#         KeyCorp
# Summit Materials, Inc.
# Gibson Energy Inc.
# HCW Biologics Inc.
# Essential Metals Limited
# EVI Industries, Inc.
# Koenig & Bauer AG
# Microchip Technology Incorporated
# Corbus Pharmaceuticals Holdings, Inc.
# Audalia Resources Limited
# Enerflex Ltd.
# MFA Financial, Inc.
# Strike Resources Limited
# Altech Chemicals Ltd
# HV Bancorp, Inc.
# Zymeworks Inc.
# iBio, Inc.
# Winnebago Industries, Inc.
# Terns Pharmaceuticals, Inc.
# Canadian Tire Corporation
# Prodigy Gold NL
# Alien Metals Limited
# Urban Logistics REIT plc
# Xero Limited
# Dunedin Enterprise Investment Trust PLC
# Cofinimmo
# Maxeon Solar Technologies, Ltd.
# Hagerty, Inc.
# Universal Electronics Inc.
# Lipocine Inc.
# ICICI Bank
# CareTrust REIT, Inc.
# Charles & Colvard, Ltd.
# Renold plc
# LVMH
# Advantage Solutions Inc.
# Harworth Group plc
# Johns Lyng Group Limited
# Nevro Corp.
# Ameresco, Inc.
# 2025-02-24T22:23:14 | INFO | model_answers=
# [{'result_name': 'Nevro Corp.', 'result_list_position': '39', 'result_prob': 1.0}, {'result_name': 'Nevro Corp.', 'result_list_position': '39', 'result_prob': 1.0}, {'result_name': 'Nevro Corp.', 'result_list_position': '39', 'result_prob': 1}]
# 2025-02-24T22:23:14 | INFO | subset_documents_to_look_through=[38]
#  97%|█████████▋| 29/30 [18:46<00:40, 40.13s/it]2025-02-24T22:23:14 | INFO |  97%|█████████▋| 29/30 [18:46<00:40, 40.13s/it]
# 2025-02-24T22:23:14 | INFO | msg=
# Find company names in this question. There could be zero or more company names
#     ---
#     Output format:
#     The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#     The output is a JSON that corresponds to the following schema:
#     {
#         "type": "object",
#         "properties": {
#             "result": {
#                 "description": "One company name",
#                 "type": "array",
#                 "items": {
#                     "type": "string"
#                 }
#             },
#             "result_prob": {
#                 "description": "Probability that the result is the right one. Float from 0 to 1.",
#                 "type": "number"
#             }
#         },
#         "required": [
#             "result",
#             "result_prob",
#         ]
#     }
#
#     ---
#     Question:
#     What was the largest single spending of Maxeon Solar Technologies, Ltd. on executive compensation in USD?
#
# 2025-02-24T22:23:30 | INFO | model_answers=
# [{'result': ['Maxeon Solar Technologies, Ltd.'], 'result_prob': 1.0}, {'result': ['Maxeon Solar Technologies, Ltd.'], 'result_prob': 1.0}, {'result': ['Maxeon Solar Technologies, Ltd.'], 'result_prob': 1.0}]
# 2025-02-24T22:23:30 | INFO | list_companies=['Maxeon Solar Technologies, Ltd.']
# 2025-02-24T22:23:31 | INFO | msg=
# Find this company name in the following list.
#         ---
#         Output format:
#         The output should start with @@@ and end with @@@. If the result is empty it should still correspond to the JSON schema and the result should be and empty array.
#         The output is a JSON that corresponds to the following schema:
#         {
#             "type": "object",
#             "properties": {
#                 "result_name": {
#                     "description": "The company name found in list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_list_position": {
#                     "description": "The position of the found company in a list. If not found return N/A",
#                     "type": "string",
#                 },
#                 "result_prob": {
#                     "description": "Probability that the result is the right one. Float from 0 to 1.",
#                     "type": "number"
#                 }
#             },
#             "required": [
#                 "result",
#                 "result_list_position",
#                 "result_prob",
#             ]
#         }
#
#         ---
#         Company name to find:
#         Maxeon Solar Technologies, Ltd.
#         ---
#         List of companies:
#         KeyCorp
# Summit Materials, Inc.
# Gibson Energy Inc.
# HCW Biologics Inc.
# Essential Metals Limited
# EVI Industries, Inc.
# Koenig & Bauer AG
# Microchip Technology Incorporated
# Corbus Pharmaceuticals Holdings, Inc.
# Audalia Resources Limited
# Enerflex Ltd.
# MFA Financial, Inc.
# Strike Resources Limited
# Altech Chemicals Ltd
# HV Bancorp, Inc.
# Zymeworks Inc.
# iBio, Inc.
# Winnebago Industries, Inc.
# Terns Pharmaceuticals, Inc.
# Canadian Tire Corporation
# Prodigy Gold NL
# Alien Metals Limited
# Urban Logistics REIT plc
# Xero Limited
# Dunedin Enterprise Investment Trust PLC
# Cofinimmo
# Maxeon Solar Technologies, Ltd.
# Hagerty, Inc.
# Universal Electronics Inc.
# Lipocine Inc.
# ICICI Bank
# CareTrust REIT, Inc.
# Charles & Colvard, Ltd.
# Renold plc
# LVMH
# Advantage Solutions Inc.
# Harworth Group plc
# Johns Lyng Group Limited
# Nevro Corp.
# Ameresco, Inc.
# 2025-02-24T22:23:58 | INFO | model_answers=
# [{'result_name': 'Maxeon Solar Technologies, Ltd.', 'result_list_position': '27', 'result_prob': 1.0}, {'result_name': 'Maxeon Solar Technologies, Ltd.', 'result_list_position': '27', 'result_prob': 1.0}, {'result_name': 'Maxeon Solar Technologies, Ltd.', 'result_list_position': '27', 'result_prob': 1.0}]
# 2025-02-24T22:23:58 | INFO | subset_documents_to_look_through=[26]
# 100%|██████████| 30/30 [19:30<00:00, 39.02s/it]

# %%
df_temp_answers = pd.DataFrame(temp_answers)
df_temp_answers.to_csv(f"../notebooks_logging/find_files/{now_str}/04 temp_answers.csv", index=False)
df_temp_answers.to_csv(f"../data_temp/04 temp_answers.csv", index=False)
df_temp_answers.to_parquet(f"../data_temp/04 temp_answers.parquet", index=False)
df_temp_answers
# Out:
#                                         question_text     kind  \
# 0   According to the annual report, what is the Op...   number
# 1   According to the annual report, what is the Op...   number
# 2   Did Cofinimmo outline any new ESG initiatives ...  boolean
# 3   What is the total number of employees let go b...   number
# 4   Which leadership **positions** changed at Reno...    names
# 5   What was the Gross margin (%) for Charles & Co...   number
# 6   What was the Capital expenditures (in GBP) for...   number
# 7   What was the Capital expenditures (in USD) for...   number
# 8   What are the names of new products launched by...    names
# 9   For Lipocine Inc., what was the value of Numbe...   number
# 10  According to the annual report, what is the To...   number
# 11  For Lipocine Inc., what was the value of Value...   number
# 12  According to the annual report, what is the Op...   number
# 13  According to the annual report, what is the To...   number
# 14  Did Charles & Colvard, Ltd. mention any ongoin...  boolean
# 15  Which leadership **positions** changed at Ener...    names
# 16  Did HV Bancorp, Inc. mention any mergers or ac...  boolean
# 17  For Alien Metals Limited, what was the value o...   number
# 18  For Renold plc, what was the value of Warehous...   number
# 19  According to the annual report, what is the Op...   number
# 20  According to the annual report, what is the To...   number
# 21  Did Canadian Tire Corporation announce a share...  boolean
# 22  Which leadership **positions** changed at Cana...    names
# 23  Did LVMH mention any mergers or acquisitions i...  boolean
# 24  For Winnebago Industries, Inc., what was the v...   number
# 25  For Johns Lyng Group Limited, what was the val...   number
# 26  Did Cofinimmo announce any changes to its divi...  boolean
# 27  What was the value of Distribution network len...   number
# 28  What was the value of Healthcare plan membersh...   number
# 29  What was the largest single spending of Maxeon...     name
#
#    documents_to_look_through
# 0                       [13]
# 1                       [25]
# 2                       [25]
# 3                       [27]
# 4                       [33]
# 5                       [32]
# 6                       [36]
# 7                       [32]
# 8                       [15]
# 9                       [29]
# 10                      [17]
# 11                      [29]
# 12                       [9]
# 13                      [29]
# 14                      [32]
# 15                      [10]
# 16                      [14]
# 17                      [21]
# 18                      [33]
# 19                      [29]
# 20                      [25]
# 21                      [19]
# 22                      [19]
# 23                      [34]
# 24                      [17]
# 25                      [37]
# 26                      [25]
# 27                      [26]
# 28                      [38]
# 29                      [26]

# %%
all_pdfs = []
for i, row in df_temp_answers.iterrows():
    all_pdfs += row["documents_to_look_through"]
li(all_pdfs)
# Out:
# 2025-02-25T12:10:25 | INFO | [13, 25, 25, 27, 33, 32, 36, 32, 15, 29, 17, 29, 9, 29, 32, 10, 14, 21, 33, 29, 25, 19, 19, 34, 17, 37, 25, 26, 38, 26]

# %%
doc_ids = pd.Series(all_pdfs).drop_duplicates().sort_values()
li(doc_ids)
# Out:
# 2025-02-25T12:18:52 | INFO | 12     9
# 15    10
# 0     13
# 16    14
# 8     15
# 10    17
# 21    19
# 17    21
# 1     25
# 27    26
# 3     27
# 9     29
# 5     32
# 4     33
# 23    34
# 6     36
# 25    37
# 28    38
# dtype: int64

# %%
df_subset2 = pd.DataFrame(subset)
df_subset2["is_in_questions"] = df_subset.index.isin(doc_ids)
df_subset2.to_csv(f"../notebooks_logging/find_files/{now_str}/04 subset.csv", index=False)
df_subset2.to_parquet(f"../notebooks_logging/find_files/{now_str}/04 subset.parquet", index=False)
df_subset2.to_csv(f"../data_temp/04 subset.csv", index=False)
df_subset2.to_parquet(f"../data_temp/04 subset.parquet", index=False)
li(f"../notebooks_logging/find_files/{now_str}/04 subset.csv")
df_subset2
# Out:
# 2025-02-25T12:21:19 | INFO | ../notebooks_logging/find_files/20250224_220427/04 subset.csv
#                                         sha1  cur  \
# 0   0a9e39e1d2e176f3a766a0e86af82772f1654a6e  USD
# 1   20c4badd4303f7aba1a298d84be3722fa84e0c67  USD
# 2   30b729c124a24ff21f37431dab6b58dfe7ba56fa  USD
# 3   42f03832077a92b3b34855cb7f9ef93563143838  EUR
# 4   49a9bf0542f3e5ff0250064bfed4369ecf6c8a09  USD
# 5   54e625a049a1713eb5a338b64858c06d74e52489  USD
# 6   56262704bde6b584dcebfa644faa23a953498a79  EUR
# 7   58b196e02c2d9749d968a29039e9c2b29d3d31e1  USD
# 8   5ac3ccdec033f81fab4c2ed9ae86553f4904a450  EUR
# 9   601aba58deffc81230c837404aa883de0d1dde1c  USD
# 10  612279ce81b538da24834af47131cc73e8c01a80  USD
# 11  61c082634d8902124bd48f55ab93ca0fb0599462  USD
# 12  62367207e1e1747a92aaba83055fea26e9a2d684  USD
# 13  63688d5d0b4f12e9f847c5407439a1ec46047a4a  USD
# 14  69a9dcb0bb6a46e2ff9f969d035e1774a2d49ef1  USD
# 15  69b472e4c05986db72ff8e547bb220e2d222b7ef  USD
# 16  6df434795a611c7fc88c75c728a96e400fc5b74d  RUB
# 17  7820b6e9487202b30f2883a6df91ae76f9461f2f  USD
# 18  79ffb9b8682aa565172233c070a47d944464644c  EUR
# 19  7c55d7900a241e732c145687598d43c915a678f9  USD
# 20  873f84bbc485e5c04065c9b13b15e7129bd255fe  USD
# 21  8dd1306c26c63913495fe81dde5180033b39fc44  AUD
# 22  91aca730786f67b17ddcdb92319f859c5745ae74  GBP
# 23  9938e66d5f0b65c66c8a404f02c1301d32991666  USD
# 24  9b3fa9062a804f0f5a5dbfa46309ed3354cd680b  GBP
# 25  9cc771c2171bacc138cda4e7d68b8b427a514d81  EUR
# 26  a34c22665bada80d76b98b0e794096aefc06758a  USD
# 27  a6f23184a87f3343f17e8e8ed08f604615cdefc1  AUD
# 28  b03044c60d02a0a5557f95f6afb59e5ffc487799  USD
# 29  c51f3c5aff7bea6fbc0bb7537838fa2f44f35c23  USD
# 30  cca42744d1a97475ccd14a5c2b98876b6d379982  AUD
# 31  cd9239df47b2f0addd9cdd50d0fab4494414bba5  USD
# 32  d3a834539b046a49708161a6c0d35aad29dd15ec  USD
# 33  da8afefdc3840175c9f26a4dbbed05e250a342cc  GBP
# 34  dda7722dd2e90c9942ed383957b527873cc74174  EUR
# 35  ea4b61f74a604df117176e74b11f5780fb473a31  USD
# 36  ed55750eae9cb7d893e6484b92496639172717cd  GBP
# 37  f393170837ab7636d83fdc105279dfc61ebeb017  USD
# 38  f75ff9d631e7efdb86db68ab8ba395de221d9019  EUR
# 39  f973dd219c534accb0d4e72d8e12f51284d48d10  USD
#
#                                company_name         major_industry  \
# 0                                   KeyCorp     Financial Services
# 1                    Summit Materials, Inc.     Financial Services
# 2                        Gibson Energy Inc.   Energy and Utilities
# 3                        HCW Biologics Inc.             Healthcare
# 4                  Essential Metals Limited             Technology
# 5                      EVI Industries, Inc.                 Retail
# 6                         Koenig & Bauer AG             Technology
# 7         Microchip Technology Incorporated             Technology
# 8     Corbus Pharmaceuticals Holdings, Inc.        Pharmaceuticals
# 9                 Audalia Resources Limited             Technology
# 10                            Enerflex Ltd.   Energy and Utilities
# 11                      MFA Financial, Inc.     Financial Services
# 12                 Strike Resources Limited   Energy and Utilities
# 13                     Altech Chemicals Ltd             Technology
# 14                         HV Bancorp, Inc.     Financial Services
# 15                           Zymeworks Inc.             Healthcare
# 16                               iBio, Inc.             Healthcare
# 17               Winnebago Industries, Inc.             Automotive
# 18              Terns Pharmaceuticals, Inc.             Healthcare
# 19                Canadian Tire Corporation                 Retail
# 20                          Prodigy Gold NL        Pharmaceuticals
# 21                     Alien Metals Limited             Technology
# 22                 Urban Logistics REIT plc  Transport & Logistics
# 23                             Xero Limited             Technology
# 24  Dunedin Enterprise Investment Trust PLC     Financial Services
# 25                                Cofinimmo             Healthcare
# 26          Maxeon Solar Technologies, Ltd.   Energy and Utilities
# 27                            Hagerty, Inc.     Financial Services
# 28               Universal Electronics Inc.             Technology
# 29                            Lipocine Inc.             Healthcare
# 30                               ICICI Bank     Financial Services
# 31                     CareTrust REIT, Inc.             Healthcare
# 32                  Charles & Colvard, Ltd.        Pharmaceuticals
# 33                               Renold plc  Transport & Logistics
# 34                                     LVMH                 Retail
# 35                 Advantage Solutions Inc.                 Retail
# 36                       Harworth Group plc  Transport & Logistics
# 37                 Johns Lyng Group Limited             Technology
# 38                              Nevro Corp.             Healthcare
# 39                           Ameresco, Inc.   Energy and Utilities
#
#     mentions_recent_mergers_and_acquisitions  has_leadership_changes  \
# 0                                       True                    True
# 1                                       True                    True
# 2                                      False                   False
# 3                                       True                   False
# 4                                       True                   False
# 5                                       True                   False
# 6                                       True                    True
# 7                                       True                    True
# 8                                       True                   False
# 9                                      False                    True
# 10                                      True                    True
# 11                                      True                   False
# 12                                     False                   False
# 13                                      True                   False
# 14                                      True                   False
# 15                                      True                   False
# 16                                      True                   False
# 17                                      True                    True
# 18                                      True                   False
# 19                                      True                    True
# 20                                      True                    True
# 21                                      True                    True
# 22                                      True                    True
# 23                                      True                    True
# 24                                      True                   False
# 25                                      True                   False
# 26                                     False                   False
# 27                                      True                    True
# 28                                     False                   False
# 29                                      True                   False
# 30                                     False                   False
# 31                                      True                    True
# 32                                     False                    True
# 33                                      True                    True
# 34                                      True                   False
# 35                                      True                   False
# 36                                     False                    True
# 37                                      True                    True
# 38                                     False                   False
# 39                                      True                   False
#
#     has_layoffs  has_executive_compensation  has_rnd_investment_numbers  \
# 0         False                        True                        True
# 1         False                        True                       False
# 2         False                        True                       False
# 3         False                        True                        True
# 4         False                        True                        True
# 5         False                        True                       False
# 6         False                        True                        True
# 7         False                        True                        True
# 8         False                        True                        True
# 9         False                        True                        True
# 10        False                        True                       False
# 11        False                        True                       False
# 12        False                        True                       False
# 13        False                        True                        True
# 14        False                        True                       False
# 15        False                        True                        True
# 16        False                        True                        True
# 17        False                        True                       False
# 18        False                        True                        True
# 19        False                        True                        True
# 20        False                        True                       False
# 21        False                        True                       False
# 22        False                        True                       False
# 23        False                        True                        True
# 24        False                        True                       False
# 25        False                        True                        True
# 26        False                        True                        True
# 27         True                        True                        True
# 28        False                        True                        True
# 29        False                        True                        True
# 30        False                        True                        True
# 31        False                        True                       False
# 32        False                        True                       False
# 33        False                        True                        True
# 34        False                        True                        True
# 35         True                        True                       False
# 36        False                        True                       False
# 37        False                        True                       False
# 38        False                        True                        True
# 39        False                        True                        True
#
#     has_new_product_launches  ...  has_dividend_policy_changes  \
# 0                       True  ...                         True
# 1                      False  ...                        False
# 2                      False  ...                         True
# 3                       True  ...                        False
# 4                      False  ...                        False
# 5                      False  ...                        False
# 6                       True  ...                        False
# 7                       True  ...                        False
# 8                       True  ...                        False
# 9                       True  ...                        False
# 10                      True  ...                         True
# 11                     False  ...                        False
# 12                     False  ...                        False
# 13                      True  ...                        False
# 14                      True  ...                        False
# 15                      True  ...                        False
# 16                      True  ...                        False
# 17                      True  ...                         True
# 18                      True  ...                        False
# 19                      True  ...                         True
# 20                     False  ...                        False
# 21                     False  ...                        False
# 22                     False  ...                        False
# 23                      True  ...                        False
# 24                     False  ...                         True
# 25                     False  ...                         True
# 26                      True  ...                        False
# 27                      True  ...                        False
# 28                      True  ...                        False
# 29                      True  ...                        False
# 30                      True  ...                         True
# 31                     False  ...                        False
# 32                      True  ...                        False
# 33                      True  ...                        False
# 34                      True  ...                        False
# 35                     False  ...                        False
# 36                      True  ...                         True
# 37                      True  ...                         True
# 38                      True  ...                        False
# 39                      True  ...                        False
#
#     has_share_buyback_plans  has_capital_structure_changes  \
# 0                      True                          False
# 1                      True                          False
# 2                      True                          False
# 3                     False                          False
# 4                     False                          False
# 5                     False                          False
# 6                     False                          False
# 7                      True                           True
# 8                     False                          False
# 9                     False                          False
# 10                    False                           True
# 11                    False                          False
# 12                    False                          False
# 13                    False                          False
# 14                     True                          False
# 15                    False                          False
# 16                    False                           True
# 17                     True                           True
# 18                    False                          False
# 19                     True                          False
# 20                    False                          False
# 21                    False                           True
# 22                    False                          False
# 23                    False                          False
# 24                     True                          False
# 25                    False                          False
# 26                    False                          False
# 27                    False                          False
# 28                    False                          False
# 29                    False                          False
# 30                    False                          False
# 31                    False                          False
# 32                    False                          False
# 33                     True                           True
# 34                    False                          False
# 35                     True                          False
# 36                    False                          False
# 37                    False                          False
# 38                    False                          False
# 39                    False                          False
#
#     mentions_new_risk_factors  has_guidance_updates  \
# 0                        True                  True
# 1                        True                 False
# 2                       False                 False
# 3                        True                  True
# 4                        True                 False
# 5                        True                 False
# 6                        True                  True
# 7                        True                  True
# 8                        True                  True
# 9                        True                 False
# 10                       True                  True
# 11                       True                 False
# 12                      False                 False
# 13                       True                 False
# 14                       True                 False
# 15                       True                  True
# 16                       True                 False
# 17                       True                 False
# 18                       True                  True
# 19                       True                  True
# 20                      False                 False
# 21                       True                 False
# 22                       True                 False
# 23                       True                  True
# 24                       True                 False
# 25                       True                  True
# 26                       True                 False
# 27                       True                  True
# 28                       True                  True
# 29                       True                 False
# 30                       True                 False
# 31                       True                 False
# 32                       True                  True
# 33                       True                  True
# 34                       True                  True
# 35                       True                 False
# 36                       True                 False
# 37                      False                 False
# 38                       True                 False
# 39                       True                  True
#
#     has_regulatory_or_litigation_issues  has_strategic_restructuring  \
# 0                                  True                        False
# 1                                 False                        False
# 2                                  True                        False
# 3                                  True                        False
# 4                                 False                        False
# 5                                 False                        False
# 6                                 False                         True
# 7                                  True                        False
# 8                                  True                        False
# 9                                 False                        False
# 10                                 True                         True
# 11                                 True                        False
# 12                                False                        False
# 13                                False                        False
# 14                                False                        False
# 15                                 True                        False
# 16                                 True                         True
# 17                                 True                        False
# 18                                 True                        False
# 19                                False                        False
# 20                                False                         True
# 21                                False                        False
# 22                                False                        False
# 23                                False                        False
# 24                                False                        False
# 25                                False                        False
# 26                                 True                        False
# 27                                 True                         True
# 28                                False                         True
# 29                                 True                        False
# 30                                False                        False
# 31                                 True                        False
# 32                                 True                        False
# 33                                False                         True
# 34                                False                        False
# 35                                 True                        False
# 36                                False                        False
# 37                                False                        False
# 38                                 True                        False
# 39                                 True                        False
#
#     has_supply_chain_disruptions  has_esg_initiatives  is_in_questions
# 0                          False                 True            False
# 1                           True                 True            False
# 2                          False                False            False
# 3                          False                False            False
# 4                          False                 True            False
# 5                           True                False            False
# 6                           True                 True            False
# 7                           True                 True            False
# 8                          False                False            False
# 9                          False                False             True
# 10                          True                 True             True
# 11                         False                False            False
# 12                         False                False            False
# 13                         False                 True             True
# 14                         False                False             True
# 15                         False                False             True
# 16                          True                False            False
# 17                          True                 True             True
# 18                         False                False            False
# 19                          True                 True             True
# 20                         False                 True            False
# 21                         False                False             True
# 22                         False                 True            False
# 23                         False                 True            False
# 24                         False                False            False
# 25                         False                 True             True
# 26                          True                False             True
# 27                         False                False             True
# 28                         False                 True            False
# 29                         False                False             True
# 30                         False                 True            False
# 31                          True                 True            False
# 32                          True                 True             True
# 33                          True                 True             True
# 34                          True                 True             True
# 35                         False                 True            False
# 36                         False                 True             True
# 37                         False                 True             True
# 38                          True                False             True
# 39                          True                 True            False
#
# [40 rows x 22 columns]
